# %%
import os
import sys

import numpy as np
import scipy.sparse.csgraph

from Cluster import Cluster
from sklearn import metrics
from ast import literal_eval

from Visualization import plot_clusters


# Inserts joined item into candidates list only if its dimensionality fits
def insert_if_join_condition(candidates, item, item2, current_dim):
    joined = []
    for i in range(len(item)):
        joined.append(item[i])
    for i in range(len(item2)):
        joined.append(item2[i])

    # Count number of dimensions
    dims = set()
    for i in range(len(joined)):
        dims.add(int(joined[i][0]))

    # Insert if it fits
    if len(dims) == current_dim:
        candidates.append(joined)


# Prune all candidates, which has a (k-1) dimensional projection not in (k-1) dim dense units
def prune(candidates, prev_dim_dense_units):
    for i in range(len(candidates)):
        for j in range(len(candidates[i])):
            if not prev_dim_dense_units.__contains__([candidates[i][j]]):
                candidates.remove(candidates[i])
                break


def self_join(prev_dim_dense_units, dim):
    candidates = []
    for i in range(len(prev_dim_dense_units)):
        for j in range(i + 1, len(prev_dim_dense_units)):
            insert_if_join_condition(
                candidates, prev_dim_dense_units[i], prev_dim_dense_units[j], dim)
    return candidates


def is_data_in_projection(tuple, candidate, xsi):
    for dim in candidate:
        element = tuple[dim[0]]
        if int(element * xsi % xsi) != dim[1]:
            return False
    return True


def get_dense_units_for_dim(data, prev_dim_dense_units, dim, xsi, tau):
    candidates = self_join(prev_dim_dense_units, dim)
    prune(candidates, prev_dim_dense_units)

    # Count number of elements in candidates
    projection = np.zeros(len(candidates))
    number_of_data_points = np.shape(data)[0]
    for dataIndex in range(number_of_data_points):
        for i in range(len(candidates)):
            if is_data_in_projection(data[dataIndex], candidates[i], xsi):
                projection[i] += 1
    print("projection: ", projection)

    # Return elements above density threshold
    is_dense = projection > tau * number_of_data_points
    print("is_dense: ", is_dense)
    return np.array(candidates)[is_dense]


def build_graph_from_dense_units(dense_units):
    graph = np.identity(len(dense_units))
    for i in range(len(dense_units)):
        for j in range(len(dense_units)):
            graph[i, j] = get_edge(dense_units[i], dense_units[j])
    return graph


def get_edge(node1, node2):
    dim = len(node1)
    distance = 0

    for i in range(dim):
        if node1[i][0] != node2[i][0]:
            return 0
        distance += abs(node1[i][1] - node2[i][1])
        if distance > 1:
            return 0
    return 1


def save_to_file(clusters, file_name):
    file = open(os.path.join(os.path.abspath(os.path.dirname(
        __file__)), file_name), encoding='utf-8', mode="w+")
    for i, c in enumerate(clusters):
        c.id = i
        file.write("Cluster " + str(i) + ":\n" + str(c))
    file.close()


def get_cluster_data_point_ids(data, cluster_dense_units, xsi):
    point_ids = set()

    # Loop through all dense unit
    for i in range(np.shape(cluster_dense_units)[0]):
        tmp_ids = set(range(np.shape(data)[0]))
        # Loop through all dimensions of dense unit
        for j in range(np.shape(cluster_dense_units)[1]):
            feature_index = cluster_dense_units[i][j][0]
            range_index = cluster_dense_units[i][j][1]
            tmp_ids = tmp_ids & set(
                np.where(np.floor(data[:, feature_index] * xsi % xsi) == range_index)[0])
        point_ids = point_ids | tmp_ids

    return point_ids


def get_clusters(dense_units, data, xsi):
    graph = build_graph_from_dense_units(dense_units)
    number_of_components, component_list = scipy.sparse.csgraph.connected_components(
        graph, directed=False)

    dense_units = np.array(dense_units)
    clusters = []
    # For every cluster
    for i in range(number_of_components):
        # Get dense units of the cluster
        cluster_dense_units = dense_units[np.where(component_list == i)]
        print("cluster_dense_units: ", cluster_dense_units.tolist())

        # Get dimensions of the cluster
        dimensions = set()
        for j in range(len(cluster_dense_units)):
            for k in range(len(cluster_dense_units[j])):
                dimensions.add(cluster_dense_units[j][k][0])

        # Get points of the cluster
        cluster_data_point_ids = get_cluster_data_point_ids(
            data, cluster_dense_units, xsi)
        # Add cluster to list
        clusters.append(Cluster(cluster_dense_units,
                                dimensions, cluster_data_point_ids))
    #print(clusters)
    return clusters


def get_one_dim_dense_units(data, tau, xsi):
    number_of_data_points = np.shape(data)[0]
    number_of_features = np.shape(data)[1]
    projection = np.zeros((xsi, number_of_features))
    for f in range(number_of_features):
        for element in data[:, f]:
            projection[int(element * xsi % xsi), f] += 1
    print("1D projection:\n", projection, "\n")
    is_dense = projection > tau * number_of_data_points
    print("is_dense:\n", is_dense)
    one_dim_dense_units = []
    for f in range(number_of_features):
        for unit in range(xsi):
            if is_dense[unit, f]:
                one_dim_dense_units.append([[f, unit]])
    return one_dim_dense_units


# Normalize data in all features (1e-5 padding is added because clustering works on [0,1) interval)
def normalize_features(data):
    normalized_data = data
    number_of_features = np.shape(normalized_data)[1]
    for f in range(number_of_features):
        normalized_data[:, f] -= min(normalized_data[:, f]) - 1e-5
        normalized_data[:, f] *= 1 / (max(normalized_data[:, f]) + 1e-5)
    return normalized_data


def evaluate_clustering_performance(df, clusters, labels):
    set_of_dimensionality = set()
    for cluster in clusters:
        set_of_dimensionality.add(frozenset(cluster.dimensions))
    max_f1 =[]
    max_p = []
    # Evaluating performance in all dimensionality
    for dim in set_of_dimensionality:
        print("\nEvaluating clusters in dimension: ", list(dim))
        # Finding clusters with same dimensions
        clusters_in_dim = []
        for c in clusters:
            if c.dimensions == dim:
                clusters_in_dim.append(c)
        clustering_labels = np.zeros(np.shape(labels))
        for i, c in enumerate(clusters_in_dim):
            clustering_labels[list(c.data_point_ids)] = i + 1
            clustering_labels1 = clustering_labels.astype(int)
            #clustering_labels1 = clustering_labels1.tolist()
            #print("clusterssssss", clustering_labels1)
        print("Number of clusters: ", len(clusters_in_dim))
        
        #print(dim)
        #if (list(dim) == [40]):
        #    print("label ",labels)
        #    print("predicts",clustering_labels1)
        orig_l = list(set(clustering_labels1))
        #print(orig_l)
        d = len(list(set(clustering_labels1)))
        #print("predicts labels size: ",d)
        pred_l = (np.arange(d)).tolist()
        for i in range(d):
            #print(orig_l[i])
            #print(pred_l[i])
            clustering_labels1[clustering_labels1 == orig_l[i]] = pred_l[i]
        #print(pred_l)
        #print("clusterssssss", clustering_labels1)
        best_k = d
        print(best_k)
        maxi,clus = max_ele(labels,clustering_labels1,best_k) 
        print("max index is ",maxi)
        print("max nos in ach aray",clus)
        precision,recall,f1_score = metrics(maxi,labels,clus,best_k) # get metrics
        
        f1_value = np.average(f1_score)

        print("F1-Value of the clusters is: ",f1_value)
        purity = purity_fn(df,clus,maxi,best_k)
        
        max_f1.append(f1_value)
        print(max_f1)
        max_p.append(purity)
        
    return max_f1,max_p
        #print("Number of clusters: ", len(clusters_in_dim))
        #print("Adjusted Rand index: ", metrics.adjusted_rand_score(
        #    labels, clustering_labels))
        #print("Mutual Information: ", metrics.adjusted_mutual_info_score(
        #    labels, clustering_labels))
        
        #print("Homogeneity, completeness, V-measure: ",
        #      metrics.homogeneity_completeness_v_measure(labels, clustering_labels))

        #print("Fowlkes-Mallows: ",
        #      metrics.fowlkes_mallows_score(labels, clustering_labels))


def run_clique(data, xsi, tau):
    # Finding 1 dimensional dense units
    dense_units = get_one_dim_dense_units(data, tau, xsi)

    # Getting 1 dimensional clusters
    clusters = get_clusters(dense_units, data, xsi)

    # Finding dense units and clusters for dimension > 2
    current_dim = 2
    number_of_features = np.shape(data)[1]
    while (current_dim <= number_of_features) & (len(dense_units) > 0):
        print("\n", str(current_dim), " dimensional clusters:")
        dense_units = get_dense_units_for_dim(
            data, dense_units, current_dim, xsi, tau)
        for cluster in get_clusters(dense_units, data, xsi):
            clusters.append(cluster)
        current_dim += 1

    return clusters


def read_labels(delimiter, label_column, path):
    return np.genfromtxt(path, dtype="U10", delimiter=delimiter, usecols=[label_column])


def read_data(delimiter, feature_columns, path):
    return np.genfromtxt(path, dtype=float, delimiter=delimiter, usecols=feature_columns)

import arffreader as ar

# %%
from collections import Counter

def max_ele(label,predicts,k):
    a = Counter(label) #label's count
    s = len(predicts)
    
    x = len(a)
    #print(x)
    ocr = []
    for i in range(x):
        temp = []
        for j in range(s):
            if label[j] == i:
                temp.append(predicts[j])
        ocr.append(temp)
            
    clus = []
    for i in range(x):
        y =  Counter(ocr[i])
        #print(y)
        clus_ocr = []
        for j in range(k):
            clus_ocr.append(y[j])
        
        clus.append(clus_ocr)
    #print(clus)
    
    maxi = []
    maxi_count =[]
    idx = 0
    for j in range(k):
        ma = 0 
        for i in range(x):
            if (ma < clus[i][j]):
                idx = i
            ma = max(clus[i][j],ma)
        maxi.append(idx)
        maxi_count.append(ma)
    #print(maxi)
    return maxi,clus


def metrics(maxi,label,clus,k):
    prec = []
    rec = []
    f1 = []
    ct = Counter(label)
    #print(clus)
    for j in range(k):
        x = (clus[maxi[j]][j])
        y = (sum([item[j] for item in clus]))
        z = float(x)/float(y)
        #print(z)
        prec.append(z)
        rc = (clus[maxi[j]][j])
        rec.append(float(rc)/ct[maxi[j]])
        f = (2*prec[j]*rec[j])/(prec[j]+rec[j])
        f1.append(f)

    print("precision : ",prec)
    print("recall are: ",rec)
    print("f1-score is: ",f1)
    return prec,rec,f1

def purity_fn(df,clus,maxi,k):
    shape = df.shape
    r_len = shape[0]
    num = 0
    for i in range(k):
        num = num + float(clus[maxi[i]][i])
    purity = num/r_len
    print("Purity is: ",purity)
    return purity

# %%
import arffreader as ar
import numpy as np
import pandas as pd
# Sample run: python Clique.py mouse.csv [0,1] 2 3 0.3 " " output_clusters.txt
if __name__ == "__main__":
    # Clustering with command line parameters
    '''if len(sys.argv) > 7:
        file_name = sys.argv[1]
        feature_columns = literal_eval(sys.argv[2])
        label_column = int(sys.argv[3])
        xsi = int(sys.argv[4])
        tau = float(sys.argv[5])
        delimiter = sys.argv[6]
        output_file = sys.argv[7]'''
    # Sample clustering with default parameters
    #else:
    #file_name = "datasets/Archive/diabetes.csv"
    #original_data , labels = ar.readarff("datasets/Archive/glass.arff") #read from arff
    #print(original_data)
    #original_data = np.genfromtxt('/home/munindra/Major_proj/datasets/Archive/B-cell1.csv',delimiter=',',skip_header=1 ) #path to csv file
    #print(original_data)
    # change column value here
    
    df = pd.read_csv('/home/munindra/Major_proj/datasets/Archive/B-cell3.csv',delimiter=',') #path to csv file
    df = df.replace({'ACL': 0, 'GCL': 1, 'CLL': 2, 'ABB': 3, 'FL': 4, 'TCL': 5, 'RAT': 6, 'RBB': 7, 'GCB': 8, 'NIL': 9, 'DLBCL': 10})
    original_data = df.as_matrix()
    
    sup = [item[-1] for item in original_data]
    sup = np.array(sup)
    labels = sup.ravel()
    labels = labels.astype(int)
    labels = labels.tolist()
    print(original_data)
    #feature_columns = [0, 1]
    #label_column = 74
    xsi = 10
    tau = 0.2
    delimiter = ','
    #output_file = "synthetic.txt"

    #print("Running CLIQUE algorithm on dataset, feature columns = " +
    #      str(feature_columns) + ", label column = " + str(label_column) + ", xsi = " +
    #      str(xsi) + ", tau = " + str(tau) + "\n")

    # Read in data with labels
    #path = os.path.join(os.path.abspath(os.path.dirname(__file__)), file_name)
    #original_data = read_data(delimiter, feature_columns, file_name)
    #labels = read_labels(delimiter, label_column, path)

    # Normalize each dimension to the [0,1] range
    data = normalize_features(original_data)
    #data = data[~np.isnan(data)]
    #data = data[np.isfinite(data)]
    #print(np.shape(data))
    clusters = run_clique(data=data,
                          xsi=xsi,
                          tau=tau)
    #save_to_file(clusters, output_file)
    #print("\nClusters exported to " + output_file)
    #print(clusters)
    # Evaluate results
    f1 , p = evaluate_clustering_performance(original_data, clusters, labels)
    print("f1_value is :",np.average(f1))
    print("purity is :",np.average(p))

    # Visualize clusters
    #title = ("DS: " + file_name + " - Params: Tau=" +
    #         str(tau) + " Xsi=" + str(xsi))
    #if len(feature_columns) <= 2:
    #    plot_clusters(data, clusters, title, xsi)
# Out:
# [[ 0.46      0.7       0.67     ... -0.04      0.16      0.      ]
#  [ 0.02      0.59      0.45     ... -0.14     -1.15      0.      ]
#  [-0.32     -0.63     -0.46     ...  0.29      0.25      0.      ]
#  ...
#  [ 0.09     -0.078375  0.85     ...  0.09     -0.53      2.      ]
#  [ 0.34     -0.078375  0.36     ... -0.33      0.01061   2.      ]
#  [ 0.37      0.38      0.3      ...  0.46      0.8       1.      ]]
# ('1D projection:\n', array([[ 1.,  1.,  1., ...,  3.,  2., 23.],
#        [ 5.,  1.,  4., ...,  4., 11., 22.],
#        [ 3.,  2.,  7., ...,  4., 21., 11.],
#        ...,
#        [19., 19.,  1., ...,  2.,  1.,  2.],
#        [ 9., 10.,  0., ...,  1.,  0.,  2.],
#        [ 3.,  3.,  1., ...,  1.,  1.,  1.]]), '\n')
# ('is_dense:\n', array([[False, False, False, ..., False, False,  True],
#        [False, False, False, ..., False, False,  True],
#        [False, False, False, ..., False,  True, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]]))
# ('cluster_dense_units: ', [[[0, 6]]])
# ('cluster_dense_units: ', [[[1, 6]]])
# ('cluster_dense_units: ', [[[2, 3]], [[2, 4]]])
# ('cluster_dense_units: ', [[[3, 3]], [[3, 4]]])
# ('cluster_dense_units: ', [[[4, 5]]])
# ('cluster_dense_units: ', [[[5, 2]], [[5, 3]]])
# ('cluster_dense_units: ', [[[6, 4]], [[6, 5]]])
# ('cluster_dense_units: ', [[[7, 3]]])
# ('cluster_dense_units: ', [[[8, 5]]])
# ('cluster_dense_units: ', [[[9, 4]]])
# ('cluster_dense_units: ', [[[10, 2]], [[10, 3]]])
# ('cluster_dense_units: ', [[[11, 2]], [[11, 3]]])
# ('cluster_dense_units: ', [[[12, 2]], [[12, 3]]])
# ('cluster_dense_units: ', [[[13, 1]], [[13, 2]], [[13, 3]]])
# ('cluster_dense_units: ', [[[14, 2]], [[14, 3]]])
# ('cluster_dense_units: ', [[[15, 3]], [[15, 4]]])
# ('cluster_dense_units: ', [[[16, 5]]])
# ('cluster_dense_units: ', [[[17, 4]]])
# ('cluster_dense_units: ', [[[19, 5]]])
# ('cluster_dense_units: ', [[[20, 7]], [[20, 8]]])
# ('cluster_dense_units: ', [[[21, 3]], [[21, 4]]])
# ('cluster_dense_units: ', [[[23, 3]]])
# ('cluster_dense_units: ', [[[24, 3]], [[24, 4]]])
# ('cluster_dense_units: ', [[[25, 6]], [[25, 7]]])
# ('cluster_dense_units: ', [[[26, 5]], [[26, 6]]])
# ('cluster_dense_units: ', [[[27, 5]], [[27, 6]]])
# ('cluster_dense_units: ', [[[28, 4]], [[28, 5]]])
# ('cluster_dense_units: ', [[[29, 7]]])
# ('cluster_dense_units: ', [[[30, 5]], [[30, 6]]])
# ('cluster_dense_units: ', [[[31, 5]]])
# ('cluster_dense_units: ', [[[32, 3]], [[32, 4]]])
# ('cluster_dense_units: ', [[[33, 5]]])
# ('cluster_dense_units: ', [[[34, 4]], [[34, 5]]])
# ('cluster_dense_units: ', [[[35, 4]], [[35, 5]], [[35, 6]]])
# ('cluster_dense_units: ', [[[36, 6]]])
# ('cluster_dense_units: ', [[[37, 4]]])
# ('cluster_dense_units: ', [[[38, 2]], [[38, 3]]])
# ('cluster_dense_units: ', [[[39, 3]]])
# ('cluster_dense_units: ', [[[40, 2]]])
# ('cluster_dense_units: ', [[[41, 3]]])
# ('cluster_dense_units: ', [[[42, 2]]])
# ('cluster_dense_units: ', [[[44, 3]], [[44, 4]]])
# ('cluster_dense_units: ', [[[45, 5]]])
# ('cluster_dense_units: ', [[[46, 3]], [[46, 4]]])
# ('cluster_dense_units: ', [[[47, 4]], [[47, 5]]])
# ('cluster_dense_units: ', [[[48, 5]], [[48, 6]]])
# ('cluster_dense_units: ', [[[49, 4]], [[49, 5]]])
# ('cluster_dense_units: ', [[[50, 5]], [[50, 6]], [[50, 7]]])
# ('cluster_dense_units: ', [[[51, 5]]])
# ('cluster_dense_units: ', [[[52, 5]], [[52, 6]]])
# ('cluster_dense_units: ', [[[53, 4]]])
# ('cluster_dense_units: ', [[[54, 5]]])
# ('cluster_dense_units: ', [[[55, 5]]])
# ('cluster_dense_units: ', [[[56, 5]]])
# ('cluster_dense_units: ', [[[57, 5]]])
# ('cluster_dense_units: ', [[[58, 6]]])
# ('cluster_dense_units: ', [[[59, 3]], [[59, 4]], [[59, 5]]])
# ('cluster_dense_units: ', [[[60, 4]], [[60, 5]]])
# ('cluster_dense_units: ', [[[61, 4]]])
# ('cluster_dense_units: ', [[[62, 3]], [[62, 4]]])
# ('cluster_dense_units: ', [[[63, 2]], [[63, 3]]])
# ('cluster_dense_units: ', [[[64, 3]], [[64, 4]]])
# ('cluster_dense_units: ', [[[65, 3]]])
# ('cluster_dense_units: ', [[[66, 3]], [[66, 4]]])
# ('cluster_dense_units: ', [[[68, 4]], [[68, 5]]])
# ('cluster_dense_units: ', [[[69, 3]]])
# ('cluster_dense_units: ', [[[71, 5]]])
# ('cluster_dense_units: ', [[[72, 4]]])
# ('cluster_dense_units: ', [[[73, 3]], [[73, 4]], [[73, 5]]])
# ('cluster_dense_units: ', [[[74, 6]]])
# ('cluster_dense_units: ', [[[75, 4]], [[75, 5]]])
# ('cluster_dense_units: ', [[[76, 5]]])
# ('cluster_dense_units: ', [[[78, 5]]])
# ('cluster_dense_units: ', [[[79, 5]], [[79, 6]]])
# ('cluster_dense_units: ', [[[81, 3]]])
# ('cluster_dense_units: ', [[[82, 5]]])
# ('cluster_dense_units: ', [[[83, 4]], [[83, 5]], [[83, 6]]])
# ('cluster_dense_units: ', [[[84, 4]]])
# ('cluster_dense_units: ', [[[88, 4]], [[88, 5]]])
# ('cluster_dense_units: ', [[[89, 5]]])
# ('cluster_dense_units: ', [[[90, 6]], [[90, 7]]])
# ('cluster_dense_units: ', [[[91, 5]]])
# ('cluster_dense_units: ', [[[92, 5]], [[92, 6]], [[92, 7]]])
# ('cluster_dense_units: ', [[[94, 3]]])
# ('cluster_dense_units: ', [[[95, 3]], [[95, 4]]])
# ('cluster_dense_units: ', [[[96, 4]], [[96, 5]]])
# ('cluster_dense_units: ', [[[97, 4]], [[97, 5]]])
# ('cluster_dense_units: ', [[[98, 5]]])
# ('cluster_dense_units: ', [[[99, 6]], [[99, 7]]])
# ('cluster_dense_units: ', [[[100, 6]]])
# ('cluster_dense_units: ', [[[101, 5]]])
# ('cluster_dense_units: ', [[[102, 3]]])
# ('cluster_dense_units: ', [[[103, 4]]])
# ('cluster_dense_units: ', [[[104, 5]]])
# ('cluster_dense_units: ', [[[107, 5]], [[107, 6]], [[107, 7]]])
# ('cluster_dense_units: ', [[[108, 6]]])
# ('cluster_dense_units: ', [[[109, 4]]])
# ('cluster_dense_units: ', [[[110, 5]], [[110, 6]]])
# ('cluster_dense_units: ', [[[111, 6]]])
# ('cluster_dense_units: ', [[[112, 4]], [[112, 5]]])
# ('cluster_dense_units: ', [[[113, 3]], [[113, 4]]])
# ('cluster_dense_units: ', [[[114, 3]], [[114, 4]], [[114, 5]]])
# ('cluster_dense_units: ', [[[116, 6]]])
# ('cluster_dense_units: ', [[[117, 6]]])
# ('cluster_dense_units: ', [[[118, 5]], [[118, 6]]])
# ('cluster_dense_units: ', [[[119, 4]], [[119, 5]]])
# ('cluster_dense_units: ', [[[120, 5]]])
# ('cluster_dense_units: ', [[[121, 5]]])
# ('cluster_dense_units: ', [[[122, 4]], [[122, 5]]])
# ('cluster_dense_units: ', [[[123, 6]]])
# ('cluster_dense_units: ', [[[124, 5]]])
# ('cluster_dense_units: ', [[[125, 4]], [[125, 5]], [[125, 6]]])
# ('cluster_dense_units: ', [[[126, 4]], [[126, 5]]])
# ('cluster_dense_units: ', [[[127, 3]], [[127, 4]]])
# ('cluster_dense_units: ', [[[128, 4]], [[128, 5]]])
# ('cluster_dense_units: ', [[[129, 4]]])
# ('cluster_dense_units: ', [[[130, 4]]])
# ('cluster_dense_units: ', [[[131, 4]]])
# ('cluster_dense_units: ', [[[132, 5]]])
# ('cluster_dense_units: ', [[[133, 5]]])
# ('cluster_dense_units: ', [[[134, 4]]])
# ('cluster_dense_units: ', [[[135, 6]], [[135, 7]]])
# ('cluster_dense_units: ', [[[136, 4]]])
# ('cluster_dense_units: ', [[[136, 6]]])
# ('cluster_dense_units: ', [[[137, 5]]])
# ('cluster_dense_units: ', [[[138, 4]], [[138, 5]]])
# ('cluster_dense_units: ', [[[140, 5]], [[140, 6]]])
# ('cluster_dense_units: ', [[[141, 5]], [[141, 6]]])
# ('cluster_dense_units: ', [[[142, 5]], [[142, 6]]])
# ('cluster_dense_units: ', [[[143, 4]], [[143, 5]]])
# ('cluster_dense_units: ', [[[144, 4]], [[144, 5]], [[144, 6]]])
# ('cluster_dense_units: ', [[[145, 4]], [[145, 5]]])
# ('cluster_dense_units: ', [[[146, 4]], [[146, 5]]])
# ('cluster_dense_units: ', [[[147, 5]], [[147, 6]]])
# ('cluster_dense_units: ', [[[148, 7]]])
# ('cluster_dense_units: ', [[[149, 5]], [[149, 6]]])
# ('cluster_dense_units: ', [[[150, 5]], [[150, 6]]])
# ('cluster_dense_units: ', [[[151, 5]], [[151, 6]]])
# ('cluster_dense_units: ', [[[152, 4]], [[152, 5]]])
# ('cluster_dense_units: ', [[[153, 5]]])
# ('cluster_dense_units: ', [[[155, 4]]])
# ('cluster_dense_units: ', [[[155, 6]]])
# ('cluster_dense_units: ', [[[156, 5]], [[156, 6]]])
# ('cluster_dense_units: ', [[[157, 4]], [[157, 5]]])
# ('cluster_dense_units: ', [[[158, 5]]])
# ('cluster_dense_units: ', [[[159, 4]], [[159, 5]]])
# ('cluster_dense_units: ', [[[160, 3]]])
# ('cluster_dense_units: ', [[[162, 5]]])
# ('cluster_dense_units: ', [[[163, 6]]])
# ('cluster_dense_units: ', [[[164, 5]]])
# ('cluster_dense_units: ', [[[165, 4]], [[165, 5]], [[165, 6]]])
# ('cluster_dense_units: ', [[[166, 4]], [[166, 5]]])
# ('cluster_dense_units: ', [[[167, 6]], [[167, 7]]])
# ('cluster_dense_units: ', [[[169, 5]]])
# ('cluster_dense_units: ', [[[170, 7]]])
# ('cluster_dense_units: ', [[[171, 3]]])
# ('cluster_dense_units: ', [[[172, 3]], [[172, 4]]])
# ('cluster_dense_units: ', [[[174, 5]]])
# ('cluster_dense_units: ', [[[175, 4]], [[175, 5]]])
# ('cluster_dense_units: ', [[[176, 4]], [[176, 5]], [[176, 6]]])
# ('cluster_dense_units: ', [[[177, 5]], [[177, 6]]])
# ('cluster_dense_units: ', [[[178, 4]]])
# ('cluster_dense_units: ', [[[179, 4]]])
# ('cluster_dense_units: ', [[[180, 3]]])
# ('cluster_dense_units: ', [[[182, 5]]])
# ('cluster_dense_units: ', [[[184, 4]]])
# ('cluster_dense_units: ', [[[185, 2]], [[185, 3]]])
# ('cluster_dense_units: ', [[[186, 2]], [[186, 3]], [[186, 4]]])
# ('cluster_dense_units: ', [[[187, 5]]])
# ('cluster_dense_units: ', [[[188, 4]]])
# ('cluster_dense_units: ', [[[189, 4]]])
# ('cluster_dense_units: ', [[[191, 6]], [[191, 7]]])
# ('cluster_dense_units: ', [[[192, 4]], [[192, 5]]])
# ('cluster_dense_units: ', [[[193, 5]]])
# ('cluster_dense_units: ', [[[194, 4]], [[194, 5]]])
# ('cluster_dense_units: ', [[[195, 6]], [[195, 7]]])
# ('cluster_dense_units: ', [[[196, 6]], [[196, 7]]])
# ('cluster_dense_units: ', [[[197, 4]], [[197, 5]]])
# ('cluster_dense_units: ', [[[198, 3]], [[198, 4]]])
# ('cluster_dense_units: ', [[[199, 4]]])
# ('cluster_dense_units: ', [[[200, 4]], [[200, 5]]])
# ('cluster_dense_units: ', [[[201, 5]], [[201, 6]]])
# ('cluster_dense_units: ', [[[202, 5]]])
# ('cluster_dense_units: ', [[[203, 5]], [[203, 6]]])
# ('cluster_dense_units: ', [[[204, 6]]])
# ('cluster_dense_units: ', [[[205, 4]]])
# ('cluster_dense_units: ', [[[206, 5]], [[206, 6]]])
# ('cluster_dense_units: ', [[[207, 6]], [[207, 7]]])
# ('cluster_dense_units: ', [[[208, 5]]])
# ('cluster_dense_units: ', [[[209, 5]]])
# ('cluster_dense_units: ', [[[210, 4]]])
# ('cluster_dense_units: ', [[[211, 4]], [[211, 5]]])
# ('cluster_dense_units: ', [[[213, 5]]])
# ('cluster_dense_units: ', [[[214, 5]], [[214, 6]]])
# ('cluster_dense_units: ', [[[215, 4]]])
# ('cluster_dense_units: ', [[[216, 5]]])
# ('cluster_dense_units: ', [[[217, 5]], [[217, 6]]])
# ('cluster_dense_units: ', [[[218, 6]], [[218, 7]]])
# ('cluster_dense_units: ', [[[219, 6]]])
# ('cluster_dense_units: ', [[[220, 5]], [[220, 6]]])
# ('cluster_dense_units: ', [[[221, 6]], [[221, 7]]])
# ('cluster_dense_units: ', [[[222, 4]]])
# ('cluster_dense_units: ', [[[222, 6]]])
# ('cluster_dense_units: ', [[[223, 5]]])
# ('cluster_dense_units: ', [[[224, 5]], [[224, 6]], [[224, 7]]])
# ('cluster_dense_units: ', [[[225, 4]], [[225, 5]]])
# ('cluster_dense_units: ', [[[226, 5]], [[226, 6]]])
# ('cluster_dense_units: ', [[[228, 3]], [[228, 4]]])
# ('cluster_dense_units: ', [[[230, 5]]])
# ('cluster_dense_units: ', [[[231, 6]], [[231, 7]]])
# ('cluster_dense_units: ', [[[233, 6]], [[233, 7]]])
# ('cluster_dense_units: ', [[[234, 7]]])
# ('cluster_dense_units: ', [[[235, 6]], [[235, 7]]])
# ('cluster_dense_units: ', [[[236, 6]], [[236, 7]]])
# ('cluster_dense_units: ', [[[237, 5]], [[237, 6]]])
# ('cluster_dense_units: ', [[[238, 5]], [[238, 6]]])
# ('cluster_dense_units: ', [[[239, 6]], [[239, 7]]])
# ('cluster_dense_units: ', [[[240, 6]], [[240, 7]]])
# ('cluster_dense_units: ', [[[241, 5]], [[241, 6]]])
# ('cluster_dense_units: ', [[[242, 6]], [[242, 7]]])
# ('cluster_dense_units: ', [[[243, 5]], [[243, 6]]])
# ('cluster_dense_units: ', [[[244, 5]]])
# ('cluster_dense_units: ', [[[245, 8]]])
# ('cluster_dense_units: ', [[[246, 8]]])
# ('cluster_dense_units: ', [[[247, 5]]])
# ('cluster_dense_units: ', [[[248, 5]], [[248, 6]]])
# ('cluster_dense_units: ', [[[249, 6]]])
# ('cluster_dense_units: ', [[[250, 6]]])
# ('cluster_dense_units: ', [[[251, 6]], [[251, 7]]])
# ('cluster_dense_units: ', [[[252, 5]]])
# ('cluster_dense_units: ', [[[253, 5]], [[253, 6]]])
# ('cluster_dense_units: ', [[[254, 6]], [[254, 7]]])
# ('cluster_dense_units: ', [[[255, 5]], [[255, 6]]])
# ('cluster_dense_units: ', [[[256, 7]], [[256, 8]]])
# ('cluster_dense_units: ', [[[257, 6]]])
# ('cluster_dense_units: ', [[[258, 7]]])
# ('cluster_dense_units: ', [[[259, 7]]])
# ('cluster_dense_units: ', [[[260, 6]]])
# ('cluster_dense_units: ', [[[261, 6]]])
# ('cluster_dense_units: ', [[[262, 7]]])
# ('cluster_dense_units: ', [[[263, 6]], [[263, 7]]])
# ('cluster_dense_units: ', [[[264, 7]]])
# ('cluster_dense_units: ', [[[265, 7]], [[265, 8]]])
# ('cluster_dense_units: ', [[[266, 6]], [[266, 7]]])
# ('cluster_dense_units: ', [[[267, 7]]])
# ('cluster_dense_units: ', [[[268, 6]]])
# ('cluster_dense_units: ', [[[269, 6]]])
# ('cluster_dense_units: ', [[[269, 8]]])
# ('cluster_dense_units: ', [[[270, 6]], [[270, 7]], [[270, 8]]])
# ('cluster_dense_units: ', [[[271, 6]], [[271, 7]], [[271, 8]]])
# ('cluster_dense_units: ', [[[272, 7]]])
# ('cluster_dense_units: ', [[[273, 6]], [[273, 7]]])
# ('cluster_dense_units: ', [[[274, 6]], [[274, 7]]])
# ('cluster_dense_units: ', [[[275, 6]]])
# ('cluster_dense_units: ', [[[276, 5]], [[276, 6]]])
# ('cluster_dense_units: ', [[[277, 5]], [[277, 6]]])
# ('cluster_dense_units: ', [[[278, 6]]])
# ('cluster_dense_units: ', [[[279, 6]], [[279, 7]]])
# ('cluster_dense_units: ', [[[280, 4]], [[280, 5]]])
# ('cluster_dense_units: ', [[[281, 4]], [[281, 5]]])
# ('cluster_dense_units: ', [[[282, 4]], [[282, 5]]])
# ('cluster_dense_units: ', [[[283, 5]], [[283, 6]]])
# ('cluster_dense_units: ', [[[284, 5]]])
# ('cluster_dense_units: ', [[[285, 4]], [[285, 5]]])
# ('cluster_dense_units: ', [[[286, 5]], [[286, 6]]])
# ('cluster_dense_units: ', [[[287, 6]], [[287, 7]]])
# ('cluster_dense_units: ', [[[288, 7]]])
# ('cluster_dense_units: ', [[[289, 6]], [[289, 7]]])
# ('cluster_dense_units: ', [[[290, 6]], [[290, 7]]])
# ('cluster_dense_units: ', [[[291, 6]], [[291, 7]]])
# ('cluster_dense_units: ', [[[292, 6]]])
# ('cluster_dense_units: ', [[[293, 6]], [[293, 7]]])
# ('cluster_dense_units: ', [[[294, 5]], [[294, 6]]])
# ('cluster_dense_units: ', [[[295, 5]]])
# ('cluster_dense_units: ', [[[296, 6]]])
# ('cluster_dense_units: ', [[[297, 7]]])
# ('cluster_dense_units: ', [[[298, 7]]])
# ('cluster_dense_units: ', [[[299, 6]], [[299, 7]]])
# ('cluster_dense_units: ', [[[300, 5]]])
# ('cluster_dense_units: ', [[[300, 7]]])
# ('cluster_dense_units: ', [[[301, 5]]])
# ('cluster_dense_units: ', [[[301, 7]]])
# ('cluster_dense_units: ', [[[302, 6]], [[302, 7]]])
# ('cluster_dense_units: ', [[[303, 7]]])
# ('cluster_dense_units: ', [[[304, 5]]])
# ('cluster_dense_units: ', [[[306, 6]]])
# ('cluster_dense_units: ', [[[307, 7]]])
# ('cluster_dense_units: ', [[[308, 6]]])
# ('cluster_dense_units: ', [[[309, 6]]])
# ('cluster_dense_units: ', [[[312, 5]]])
# ('cluster_dense_units: ', [[[312, 7]]])
# ('cluster_dense_units: ', [[[313, 6]]])
# ('cluster_dense_units: ', [[[314, 6]]])
# ('cluster_dense_units: ', [[[315, 5]], [[315, 6]]])
# ('cluster_dense_units: ', [[[316, 6]]])
# ('cluster_dense_units: ', [[[316, 8]]])
# ('cluster_dense_units: ', [[[320, 7]], [[320, 8]]])
# ('cluster_dense_units: ', [[[321, 7]]])
# ('cluster_dense_units: ', [[[322, 6]]])
# ('cluster_dense_units: ', [[[323, 6]], [[323, 7]], [[323, 8]]])
# ('cluster_dense_units: ', [[[324, 7]], [[324, 8]]])
# ('cluster_dense_units: ', [[[325, 6]], [[325, 7]]])
# ('cluster_dense_units: ', [[[326, 6]], [[326, 7]]])
# ('cluster_dense_units: ', [[[327, 6]]])
# ('cluster_dense_units: ', [[[328, 6]]])
# ('cluster_dense_units: ', [[[329, 6]]])
# ('cluster_dense_units: ', [[[330, 6]]])
# ('cluster_dense_units: ', [[[333, 6]]])
# ('cluster_dense_units: ', [[[334, 5]]])
# ('cluster_dense_units: ', [[[335, 7]]])
# ('cluster_dense_units: ', [[[336, 4]]])
# ('cluster_dense_units: ', [[[336, 6]]])
# ('cluster_dense_units: ', [[[337, 4]]])
# ('cluster_dense_units: ', [[[338, 6]]])
# ('cluster_dense_units: ', [[[339, 6]], [[339, 7]], [[339, 8]]])
# ('cluster_dense_units: ', [[[341, 8]]])
# ('cluster_dense_units: ', [[[342, 8]]])
# ('cluster_dense_units: ', [[[343, 6]]])
# ('cluster_dense_units: ', [[[344, 5]], [[344, 6]]])
# ('cluster_dense_units: ', [[[345, 5]], [[345, 6]]])
# ('cluster_dense_units: ', [[[348, 5]], [[348, 6]]])
# ('cluster_dense_units: ', [[[349, 7]], [[349, 8]]])
# ('cluster_dense_units: ', [[[350, 6]], [[350, 7]], [[350, 8]]])
# ('cluster_dense_units: ', [[[351, 7]], [[351, 8]]])
# ('cluster_dense_units: ', [[[352, 7]], [[352, 8]]])
# ('cluster_dense_units: ', [[[353, 7]], [[353, 8]]])
# ('cluster_dense_units: ', [[[354, 7]], [[354, 8]]])
# ('cluster_dense_units: ', [[[355, 6]]])
# ('cluster_dense_units: ', [[[356, 6]], [[356, 7]], [[356, 8]]])
# ('cluster_dense_units: ', [[[357, 7]], [[357, 8]]])
# ('cluster_dense_units: ', [[[358, 7]], [[358, 8]]])
# ('cluster_dense_units: ', [[[359, 7]], [[359, 8]]])
# ('cluster_dense_units: ', [[[360, 7]], [[360, 8]]])
# ('cluster_dense_units: ', [[[361, 5]], [[361, 6]]])
# ('cluster_dense_units: ', [[[362, 6]], [[362, 7]], [[362, 8]]])
# ('cluster_dense_units: ', [[[363, 7]], [[363, 8]]])
# ('cluster_dense_units: ', [[[364, 7]], [[364, 8]]])
# ('cluster_dense_units: ', [[[365, 7]], [[365, 8]]])
# ('cluster_dense_units: ', [[[366, 6]], [[366, 7]]])
# ('cluster_dense_units: ', [[[367, 7]], [[367, 8]]])
# ('cluster_dense_units: ', [[[368, 7]], [[368, 8]]])
# ('cluster_dense_units: ', [[[369, 7]], [[369, 8]]])
# ('cluster_dense_units: ', [[[370, 7]], [[370, 8]]])
# ('cluster_dense_units: ', [[[371, 6]], [[371, 7]], [[371, 8]]])
# ('cluster_dense_units: ', [[[372, 6]], [[372, 7]]])
# ('cluster_dense_units: ', [[[373, 6]], [[373, 7]]])
# ('cluster_dense_units: ', [[[374, 6]], [[374, 7]]])
# ('cluster_dense_units: ', [[[375, 7]]])
# ('cluster_dense_units: ', [[[376, 6]], [[376, 7]]])
# ('cluster_dense_units: ', [[[377, 5]]])
# ('cluster_dense_units: ', [[[378, 5]]])
# ('cluster_dense_units: ', [[[379, 4]], [[379, 5]]])
# ('cluster_dense_units: ', [[[380, 5]]])
# ('cluster_dense_units: ', [[[380, 7]]])
# ('cluster_dense_units: ', [[[381, 5]], [[381, 6]]])
# ('cluster_dense_units: ', [[[383, 5]]])
# ('cluster_dense_units: ', [[[384, 5]], [[384, 6]]])
# ('cluster_dense_units: ', [[[385, 4]], [[385, 5]], [[385, 6]]])
# ('cluster_dense_units: ', [[[386, 6]], [[386, 7]]])
# ('cluster_dense_units: ', [[[387, 6]], [[387, 7]]])
# ('cluster_dense_units: ', [[[388, 4]]])
# ('cluster_dense_units: ', [[[390, 4]], [[390, 5]]])
# ('cluster_dense_units: ', [[[392, 5]]])
# ('cluster_dense_units: ', [[[393, 6]], [[393, 7]]])
# ('cluster_dense_units: ', [[[394, 5]], [[394, 6]]])
# ('cluster_dense_units: ', [[[395, 6]], [[395, 7]]])
# ('cluster_dense_units: ', [[[396, 6]]])
# ('cluster_dense_units: ', [[[397, 6]], [[397, 7]]])
# ('cluster_dense_units: ', [[[398, 5]]])
# ('cluster_dense_units: ', [[[399, 5]], [[399, 6]]])
# ('cluster_dense_units: ', [[[400, 7]]])
# ('cluster_dense_units: ', [[[401, 6]]])
# ('cluster_dense_units: ', [[[402, 6]], [[402, 7]]])
# ('cluster_dense_units: ', [[[403, 6]]])
# ('cluster_dense_units: ', [[[404, 6]]])
# ('cluster_dense_units: ', [[[405, 6]], [[405, 7]]])
# ('cluster_dense_units: ', [[[406, 6]], [[406, 7]]])
# ('cluster_dense_units: ', [[[407, 6]], [[407, 7]]])
# ('cluster_dense_units: ', [[[408, 6]], [[408, 7]]])
# ('cluster_dense_units: ', [[[409, 4]]])
# ('cluster_dense_units: ', [[[410, 6]], [[410, 7]]])
# ('cluster_dense_units: ', [[[412, 2]], [[412, 3]], [[412, 4]]])
# ('cluster_dense_units: ', [[[413, 4]], [[413, 5]]])
# ('cluster_dense_units: ', [[[414, 4]], [[414, 5]]])
# ('cluster_dense_units: ', [[[415, 4]]])
# ('cluster_dense_units: ', [[[416, 4]], [[416, 5]]])
# ('cluster_dense_units: ', [[[417, 3]], [[417, 4]]])
# ('cluster_dense_units: ', [[[419, 4]], [[419, 5]]])
# ('cluster_dense_units: ', [[[420, 3]], [[420, 4]]])
# ('cluster_dense_units: ', [[[421, 4]]])
# ('cluster_dense_units: ', [[[423, 5]], [[423, 6]]])
# ('cluster_dense_units: ', [[[426, 6]]])
# ('cluster_dense_units: ', [[[427, 6]]])
# ('cluster_dense_units: ', [[[428, 6]]])
# ('cluster_dense_units: ', [[[429, 4]]])
# ('cluster_dense_units: ', [[[430, 5]]])
# ('cluster_dense_units: ', [[[442, 4]]])
# ('cluster_dense_units: ', [[[443, 3]]])
# ('cluster_dense_units: ', [[[444, 4]]])
# ('cluster_dense_units: ', [[[445, 5]]])
# ('cluster_dense_units: ', [[[446, 4]]])
# ('cluster_dense_units: ', [[[447, 4]], [[447, 5]]])
# ('cluster_dense_units: ', [[[448, 4]], [[448, 5]]])
# ('cluster_dense_units: ', [[[449, 4]]])
# ('cluster_dense_units: ', [[[450, 5]]])
# ('cluster_dense_units: ', [[[451, 6]]])
# ('cluster_dense_units: ', [[[452, 5]]])
# ('cluster_dense_units: ', [[[453, 5]]])
# ('cluster_dense_units: ', [[[454, 4]]])
# ('cluster_dense_units: ', [[[455, 5]]])
# ('cluster_dense_units: ', [[[456, 6]], [[456, 7]], [[456, 8]]])
# ('cluster_dense_units: ', [[[457, 2]]])
# ('cluster_dense_units: ', [[[458, 3]]])
# ('cluster_dense_units: ', [[[459, 3]]])
# ('cluster_dense_units: ', [[[460, 4]]])
# ('cluster_dense_units: ', [[[461, 3]], [[461, 4]]])
# ('cluster_dense_units: ', [[[462, 5]]])
# ('cluster_dense_units: ', [[[463, 5]], [[463, 6]]])
# ('cluster_dense_units: ', [[[464, 5]], [[464, 6]], [[464, 7]]])
# ('cluster_dense_units: ', [[[465, 4]], [[465, 5]]])
# ('cluster_dense_units: ', [[[466, 5]], [[466, 6]]])
# ('cluster_dense_units: ', [[[467, 5]], [[467, 6]]])
# ('cluster_dense_units: ', [[[468, 6]]])
# ('cluster_dense_units: ', [[[469, 5]], [[469, 6]]])
# ('cluster_dense_units: ', [[[470, 4]], [[470, 5]]])
# ('cluster_dense_units: ', [[[471, 5]], [[471, 6]]])
# ('cluster_dense_units: ', [[[472, 5]], [[472, 6]]])
# ('cluster_dense_units: ', [[[473, 3]], [[473, 4]]])
# ('cluster_dense_units: ', [[[474, 3]], [[474, 4]]])
# ('cluster_dense_units: ', [[[475, 3]], [[475, 4]], [[475, 5]]])
# ('cluster_dense_units: ', [[[476, 4]], [[476, 5]]])
# ('cluster_dense_units: ', [[[477, 3]], [[477, 4]]])
# ('cluster_dense_units: ', [[[478, 5]]])
# ('cluster_dense_units: ', [[[479, 2]], [[479, 3]]])
# ('cluster_dense_units: ', [[[480, 2]], [[480, 3]]])
# ('cluster_dense_units: ', [[[482, 4]]])
# ('cluster_dense_units: ', [[[483, 5]]])
# ('cluster_dense_units: ', [[[484, 5]]])
# ('cluster_dense_units: ', [[[485, 6]]])
# ('cluster_dense_units: ', [[[486, 5]]])
# ('cluster_dense_units: ', [[[487, 5]]])
# ('cluster_dense_units: ', [[[488, 4]], [[488, 5]]])
# ('cluster_dense_units: ', [[[489, 4]], [[489, 5]]])
# ('cluster_dense_units: ', [[[490, 3]], [[490, 4]]])
# ('cluster_dense_units: ', [[[491, 5]]])
# ('cluster_dense_units: ', [[[492, 5]]])
# ('cluster_dense_units: ', [[[493, 4]]])
# ('cluster_dense_units: ', [[[494, 5]]])
# ('cluster_dense_units: ', [[[495, 4]]])
# ('cluster_dense_units: ', [[[499, 5]]])
# ('cluster_dense_units: ', [[[501, 4]]])
# ('cluster_dense_units: ', [[[502, 2]], [[502, 3]]])
# ('cluster_dense_units: ', [[[503, 3]]])
# ('cluster_dense_units: ', [[[505, 6]]])
# ('cluster_dense_units: ', [[[506, 6]]])
# ('cluster_dense_units: ', [[[507, 5]]])
# ('cluster_dense_units: ', [[[510, 4]]])
# ('cluster_dense_units: ', [[[511, 2]]])
# ('cluster_dense_units: ', [[[516, 2]]])
# ('cluster_dense_units: ', [[[517, 4]]])
# ('cluster_dense_units: ', [[[518, 5]]])
# ('cluster_dense_units: ', [[[519, 5]], [[519, 6]]])
# ('cluster_dense_units: ', [[[520, 4]]])
# ('cluster_dense_units: ', [[[521, 3]]])
# ('cluster_dense_units: ', [[[522, 3]]])
# ('cluster_dense_units: ', [[[523, 4]]])
# ('cluster_dense_units: ', [[[524, 6]]])
# ('cluster_dense_units: ', [[[525, 6]], [[525, 7]]])
# ('cluster_dense_units: ', [[[526, 4]]])
# ('cluster_dense_units: ', [[[527, 5]]])
# ('cluster_dense_units: ', [[[528, 5]]])
# ('cluster_dense_units: ', [[[529, 5]]])
# ('cluster_dense_units: ', [[[530, 5]]])
# ('cluster_dense_units: ', [[[531, 4]]])
# ('cluster_dense_units: ', [[[532, 4]]])
# ('cluster_dense_units: ', [[[533, 4]]])
# ('cluster_dense_units: ', [[[534, 5]]])
# ('cluster_dense_units: ', [[[535, 4]]])
# ('cluster_dense_units: ', [[[536, 4]]])
# ('cluster_dense_units: ', [[[537, 3]]])
# ('cluster_dense_units: ', [[[538, 5]]])
# ('cluster_dense_units: ', [[[539, 4]], [[539, 5]]])
# ('cluster_dense_units: ', [[[540, 5]], [[540, 6]]])
# ('cluster_dense_units: ', [[[541, 6]], [[541, 7]]])
# ('cluster_dense_units: ', [[[542, 7]]])
# ('cluster_dense_units: ', [[[543, 5]]])
# ('cluster_dense_units: ', [[[544, 5]], [[544, 6]]])
# ('cluster_dense_units: ', [[[545, 4]], [[545, 5]]])
# ('cluster_dense_units: ', [[[546, 4]], [[546, 5]]])
# ('cluster_dense_units: ', [[[547, 5]]])
# ('cluster_dense_units: ', [[[548, 3]]])
# ('cluster_dense_units: ', [[[549, 5]], [[549, 6]]])
# ('cluster_dense_units: ', [[[550, 4]], [[550, 5]]])
# ('cluster_dense_units: ', [[[551, 4]]])
# ('cluster_dense_units: ', [[[552, 4]], [[552, 5]]])
# ('cluster_dense_units: ', [[[553, 5]]])
# ('cluster_dense_units: ', [[[554, 5]]])
# ('cluster_dense_units: ', [[[555, 4]]])
# ('cluster_dense_units: ', [[[557, 3]]])
# ('cluster_dense_units: ', [[[559, 4]]])
# ('cluster_dense_units: ', [[[559, 6]]])
# ('cluster_dense_units: ', [[[560, 6]]])
# ('cluster_dense_units: ', [[[561, 4]], [[561, 5]]])
# ('cluster_dense_units: ', [[[562, 4]], [[562, 5]]])
# ('cluster_dense_units: ', [[[563, 6]]])
# ('cluster_dense_units: ', [[[564, 7]]])
# ('cluster_dense_units: ', [[[565, 6]]])
# ('cluster_dense_units: ', [[[566, 6]], [[566, 7]]])
# ('cluster_dense_units: ', [[[567, 4]]])
# ('cluster_dense_units: ', [[[568, 4]]])
# ('cluster_dense_units: ', [[[569, 4]], [[569, 5]]])
# ('cluster_dense_units: ', [[[570, 5]]])
# ('cluster_dense_units: ', [[[571, 5]], [[571, 6]]])
# ('cluster_dense_units: ', [[[572, 5]]])
# ('cluster_dense_units: ', [[[573, 4]], [[573, 5]]])
# ('cluster_dense_units: ', [[[574, 5]], [[574, 6]]])
# ('cluster_dense_units: ', [[[575, 5]], [[575, 6]]])
# ('cluster_dense_units: ', [[[576, 6]]])
# ('cluster_dense_units: ', [[[577, 6]], [[577, 7]]])
# ('cluster_dense_units: ', [[[578, 5]], [[578, 6]]])
# ('cluster_dense_units: ', [[[579, 5]]])
# ('cluster_dense_units: ', [[[580, 3]], [[580, 4]]])
# ('cluster_dense_units: ', [[[581, 4]]])
# ('cluster_dense_units: ', [[[582, 4]], [[582, 5]]])
# ('cluster_dense_units: ', [[[584, 4]]])
# ('cluster_dense_units: ', [[[584, 6]]])
# ('cluster_dense_units: ', [[[585, 1]], [[585, 2]]])
# ('cluster_dense_units: ', [[[586, 2]]])
# ('cluster_dense_units: ', [[[587, 3]]])
# ('cluster_dense_units: ', [[[588, 3]], [[588, 4]], [[588, 5]]])
# ('cluster_dense_units: ', [[[589, 4]]])
# ('cluster_dense_units: ', [[[590, 4]], [[590, 5]]])
# ('cluster_dense_units: ', [[[591, 2]], [[591, 3]], [[591, 4]]])
# ('cluster_dense_units: ', [[[592, 2]], [[592, 3]]])
# ('cluster_dense_units: ', [[[593, 3]]])
# ('cluster_dense_units: ', [[[594, 4]]])
# ('cluster_dense_units: ', [[[595, 5]]])
# ('cluster_dense_units: ', [[[597, 5]], [[597, 6]]])
# ('cluster_dense_units: ', [[[600, 4]]])
# ('cluster_dense_units: ', [[[601, 7]], [[601, 8]]])
# ('cluster_dense_units: ', [[[602, 3]]])
# ('cluster_dense_units: ', [[[603, 3]]])
# ('cluster_dense_units: ', [[[604, 4]]])
# ('cluster_dense_units: ', [[[605, 4]]])
# ('cluster_dense_units: ', [[[606, 5]]])
# ('cluster_dense_units: ', [[[607, 3]], [[607, 4]]])
# ('cluster_dense_units: ', [[[608, 3]]])
# ('cluster_dense_units: ', [[[609, 2]]])
# ('cluster_dense_units: ', [[[610, 1]], [[610, 2]], [[610, 3]]])
# ('cluster_dense_units: ', [[[611, 2]], [[611, 3]]])
# ('cluster_dense_units: ', [[[612, 2]], [[612, 3]], [[612, 4]]])
# ('cluster_dense_units: ', [[[613, 4]]])
# ('cluster_dense_units: ', [[[614, 5]]])
# ('cluster_dense_units: ', [[[615, 3]], [[615, 4]]])
# ('cluster_dense_units: ', [[[616, 3]]])
# ('cluster_dense_units: ', [[[617, 6]], [[617, 7]]])
# ('cluster_dense_units: ', [[[618, 4]], [[618, 5]]])
# ('cluster_dense_units: ', [[[619, 5]]])
# ('cluster_dense_units: ', [[[620, 5]], [[620, 6]], [[620, 7]]])
# ('cluster_dense_units: ', [[[621, 6]], [[621, 7]], [[621, 8]]])
# ('cluster_dense_units: ', [[[622, 7]]])
# ('cluster_dense_units: ', [[[623, 4]], [[623, 5]]])
# ('cluster_dense_units: ', [[[624, 4]]])
# ('cluster_dense_units: ', [[[625, 5]]])
# ('cluster_dense_units: ', [[[626, 5]]])
# ('cluster_dense_units: ', [[[627, 4]]])
# ('cluster_dense_units: ', [[[628, 1]], [[628, 2]]])
# ('cluster_dense_units: ', [[[629, 4]]])
# ('cluster_dense_units: ', [[[630, 4]]])
# ('cluster_dense_units: ', [[[631, 5]]])
# ('cluster_dense_units: ', [[[632, 5]]])
# ('cluster_dense_units: ', [[[633, 4]]])
# ('cluster_dense_units: ', [[[634, 6]], [[634, 7]]])
# ('cluster_dense_units: ', [[[635, 6]], [[635, 7]]])
# ('cluster_dense_units: ', [[[636, 3]], [[636, 4]]])
# ('cluster_dense_units: ', [[[637, 2]], [[637, 3]]])
# ('cluster_dense_units: ', [[[638, 3]]])
# ('cluster_dense_units: ', [[[639, 3]], [[639, 4]]])
# ('cluster_dense_units: ', [[[640, 3]]])
# ('cluster_dense_units: ', [[[641, 3]]])
# ('cluster_dense_units: ', [[[642, 3]]])
# ('cluster_dense_units: ', [[[643, 5]], [[643, 6]]])
# ('cluster_dense_units: ', [[[644, 5]]])
# ('cluster_dense_units: ', [[[645, 5]], [[645, 6]]])
# ('cluster_dense_units: ', [[[646, 6]]])
# ('cluster_dense_units: ', [[[647, 5]]])
# ('cluster_dense_units: ', [[[648, 5]]])
# ('cluster_dense_units: ', [[[649, 4]]])
# ('cluster_dense_units: ', [[[650, 4]], [[650, 5]]])
# ('cluster_dense_units: ', [[[651, 4]]])
# ('cluster_dense_units: ', [[[652, 4]], [[652, 5]]])
# ('cluster_dense_units: ', [[[653, 4]]])
# ('cluster_dense_units: ', [[[654, 5]], [[654, 6]]])
# ('cluster_dense_units: ', [[[655, 5]]])
# ('cluster_dense_units: ', [[[656, 4]]])
# ('cluster_dense_units: ', [[[657, 4]]])
# ('cluster_dense_units: ', [[[659, 4]], [[659, 5]]])
# ('cluster_dense_units: ', [[[660, 5]]])
# ('cluster_dense_units: ', [[[661, 5]]])
# ('cluster_dense_units: ', [[[663, 4]]])
# ('cluster_dense_units: ', [[[664, 2]], [[664, 3]]])
# ('cluster_dense_units: ', [[[665, 4]], [[665, 5]]])
# ('cluster_dense_units: ', [[[666, 4]], [[666, 5]]])
# ('cluster_dense_units: ', [[[667, 4]]])
# ('cluster_dense_units: ', [[[668, 4]]])
# ('cluster_dense_units: ', [[[669, 6]]])
# ('cluster_dense_units: ', [[[670, 4]], [[670, 5]]])
# ('cluster_dense_units: ', [[[671, 6]]])
# ('cluster_dense_units: ', [[[672, 5]]])
# ('cluster_dense_units: ', [[[673, 5]]])
# ('cluster_dense_units: ', [[[674, 4]], [[674, 5]]])
# ('cluster_dense_units: ', [[[675, 5]]])
# ('cluster_dense_units: ', [[[676, 3]], [[676, 4]]])
# ('cluster_dense_units: ', [[[677, 3]], [[677, 4]]])
# ('cluster_dense_units: ', [[[678, 7]], [[678, 8]]])
# ('cluster_dense_units: ', [[[680, 3]]])
# ('cluster_dense_units: ', [[[680, 5]]])
# ('cluster_dense_units: ', [[[683, 3]]])
# ('cluster_dense_units: ', [[[684, 3]]])
# ('cluster_dense_units: ', [[[685, 4]]])
# ('cluster_dense_units: ', [[[686, 5]]])
# ('cluster_dense_units: ', [[[687, 7]]])
# ('cluster_dense_units: ', [[[688, 6]]])
# ('cluster_dense_units: ', [[[690, 4]]])
# ('cluster_dense_units: ', [[[692, 5]], [[692, 6]]])
# ('cluster_dense_units: ', [[[693, 4]], [[693, 5]]])
# ('cluster_dense_units: ', [[[694, 6]]])
# ('cluster_dense_units: ', [[[695, 5]]])
# ('cluster_dense_units: ', [[[696, 5]], [[696, 6]]])
# ('cluster_dense_units: ', [[[697, 6]]])
# ('cluster_dense_units: ', [[[698, 4]], [[698, 5]]])
# ('cluster_dense_units: ', [[[699, 4]], [[699, 5]]])
# ('cluster_dense_units: ', [[[700, 5]]])
# ('cluster_dense_units: ', [[[701, 5]]])
# ('cluster_dense_units: ', [[[702, 6]], [[702, 7]]])
# ('cluster_dense_units: ', [[[703, 5]], [[703, 6]]])
# ('cluster_dense_units: ', [[[704, 4]], [[704, 5]]])
# ('cluster_dense_units: ', [[[705, 4]]])
# ('cluster_dense_units: ', [[[707, 4]], [[707, 5]]])
# ('cluster_dense_units: ', [[[708, 3]]])
# ('cluster_dense_units: ', [[[710, 4]]])
# ('cluster_dense_units: ', [[[711, 5]], [[711, 6]]])
# ('cluster_dense_units: ', [[[712, 2]]])
# ('cluster_dense_units: ', [[[712, 4]]])
# ('cluster_dense_units: ', [[[713, 4]], [[713, 5]]])
# ('cluster_dense_units: ', [[[714, 5]]])
# ('cluster_dense_units: ', [[[715, 5]], [[715, 6]]])
# ('cluster_dense_units: ', [[[716, 5]], [[716, 6]]])
# ('cluster_dense_units: ', [[[717, 4]]])
# ('cluster_dense_units: ', [[[718, 4]]])
# ('cluster_dense_units: ', [[[719, 2]], [[719, 3]], [[719, 4]]])
# ('cluster_dense_units: ', [[[720, 4]]])
# ('cluster_dense_units: ', [[[721, 5]]])
# ('cluster_dense_units: ', [[[722, 3]], [[722, 4]]])
# ('cluster_dense_units: ', [[[723, 5]], [[723, 6]], [[723, 7]]])
# ('cluster_dense_units: ', [[[724, 4]], [[724, 5]]])
# ('cluster_dense_units: ', [[[725, 3]]])
# ('cluster_dense_units: ', [[[725, 5]]])
# ('cluster_dense_units: ', [[[726, 6]]])
# ('cluster_dense_units: ', [[[727, 6]]])
# ('cluster_dense_units: ', [[[728, 5]]])
# ('cluster_dense_units: ', [[[728, 7]]])
# ('cluster_dense_units: ', [[[733, 7]]])
# ('cluster_dense_units: ', [[[734, 7]]])
# ('cluster_dense_units: ', [[[735, 6]]])
# ('cluster_dense_units: ', [[[736, 7]]])
# ('cluster_dense_units: ', [[[738, 6]]])
# ('cluster_dense_units: ', [[[739, 5]]])
# ('cluster_dense_units: ', [[[740, 3]]])
# ('cluster_dense_units: ', [[[743, 3]]])
# ('cluster_dense_units: ', [[[749, 5]]])
# ('cluster_dense_units: ', [[[751, 5]]])
# ('cluster_dense_units: ', [[[752, 4]]])
# ('cluster_dense_units: ', [[[753, 4]], [[753, 5]]])
# ('cluster_dense_units: ', [[[754, 4]]])
# ('cluster_dense_units: ', [[[755, 3]]])
# ('cluster_dense_units: ', [[[756, 5]]])
# ('cluster_dense_units: ', [[[758, 4]]])
# ('cluster_dense_units: ', [[[759, 4]]])
# ('cluster_dense_units: ', [[[760, 4]]])
# ('cluster_dense_units: ', [[[761, 4]]])
# ('cluster_dense_units: ', [[[762, 2]]])
# ('cluster_dense_units: ', [[[763, 4]]])
# ('cluster_dense_units: ', [[[764, 3]], [[764, 4]]])
# ('cluster_dense_units: ', [[[765, 2]]])
# ('cluster_dense_units: ', [[[767, 5]]])
# ('cluster_dense_units: ', [[[768, 5]]])
# ('cluster_dense_units: ', [[[769, 5]]])
# ('cluster_dense_units: ', [[[770, 3]]])
# ('cluster_dense_units: ', [[[771, 5]]])
# ('cluster_dense_units: ', [[[775, 5]]])
# ('cluster_dense_units: ', [[[776, 2]], [[776, 3]]])
# ('cluster_dense_units: ', [[[777, 3]], [[777, 4]]])
# ('cluster_dense_units: ', [[[778, 3]]])
# ('cluster_dense_units: ', [[[781, 5]]])
# ('cluster_dense_units: ', [[[782, 6]]])
# ('cluster_dense_units: ', [[[783, 2]], [[783, 3]], [[783, 4]]])
# ('cluster_dense_units: ', [[[784, 2]], [[784, 3]], [[784, 4]]])
# ('cluster_dense_units: ', [[[785, 2]]])
# ('cluster_dense_units: ', [[[786, 3]], [[786, 4]]])
# ('cluster_dense_units: ', [[[787, 3]]])
# ('cluster_dense_units: ', [[[788, 3]]])
# ('cluster_dense_units: ', [[[789, 4]]])
# ('cluster_dense_units: ', [[[790, 3]], [[790, 4]]])
# ('cluster_dense_units: ', [[[791, 3]]])
# ('cluster_dense_units: ', [[[793, 3]]])
# ('cluster_dense_units: ', [[[794, 4]]])
# ('cluster_dense_units: ', [[[795, 3]]])
# ('cluster_dense_units: ', [[[796, 5]]])
# ('cluster_dense_units: ', [[[799, 5]]])
# ('cluster_dense_units: ', [[[800, 4]]])
# ('cluster_dense_units: ', [[[801, 3]], [[801, 4]]])
# ('cluster_dense_units: ', [[[802, 5]]])
# ('cluster_dense_units: ', [[[803, 5]]])
# ('cluster_dense_units: ', [[[804, 4]], [[804, 5]]])
# ('cluster_dense_units: ', [[[805, 4]]])
# ('cluster_dense_units: ', [[[806, 3]], [[806, 4]]])
# ('cluster_dense_units: ', [[[809, 4]], [[809, 5]]])
# ('cluster_dense_units: ', [[[810, 3]], [[810, 4]]])
# ('cluster_dense_units: ', [[[813, 5]], [[813, 6]]])
# ('cluster_dense_units: ', [[[814, 5]], [[814, 6]], [[814, 7]]])
# ('cluster_dense_units: ', [[[815, 4]], [[815, 5]]])
# ('cluster_dense_units: ', [[[816, 4]]])
# ('cluster_dense_units: ', [[[817, 4]]])
# ('cluster_dense_units: ', [[[818, 5]], [[818, 6]]])
# ('cluster_dense_units: ', [[[819, 4]], [[819, 5]]])
# ('cluster_dense_units: ', [[[820, 4]], [[820, 5]]])
# ('cluster_dense_units: ', [[[821, 5]], [[821, 6]]])
# ('cluster_dense_units: ', [[[822, 4]]])
# ('cluster_dense_units: ', [[[823, 3]], [[823, 4]]])
# ('cluster_dense_units: ', [[[824, 4]], [[824, 5]]])
# ('cluster_dense_units: ', [[[825, 5]], [[825, 6]]])
# ('cluster_dense_units: ', [[[826, 6]]])
# ('cluster_dense_units: ', [[[827, 5]]])
# ('cluster_dense_units: ', [[[828, 5]]])
# ('cluster_dense_units: ', [[[829, 4]], [[829, 5]]])
# ('cluster_dense_units: ', [[[831, 3]]])
# ('cluster_dense_units: ', [[[832, 4]]])
# ('cluster_dense_units: ', [[[833, 2]], [[833, 3]]])
# ('cluster_dense_units: ', [[[834, 2]], [[834, 3]]])
# ('cluster_dense_units: ', [[[835, 2]], [[835, 3]]])
# ('cluster_dense_units: ', [[[836, 2]], [[836, 3]]])
# ('cluster_dense_units: ', [[[837, 3]]])
# ('cluster_dense_units: ', [[[838, 3]]])
# ('cluster_dense_units: ', [[[839, 2]]])
# ('cluster_dense_units: ', [[[840, 4]], [[840, 5]]])
# ('cluster_dense_units: ', [[[841, 4]]])
# ('cluster_dense_units: ', [[[842, 4]]])
# ('cluster_dense_units: ', [[[843, 2]]])
# ('cluster_dense_units: ', [[[844, 4]]])
# ('cluster_dense_units: ', [[[845, 4]]])
# ('cluster_dense_units: ', [[[846, 1]]])
# ('cluster_dense_units: ', [[[847, 4]]])
# ('cluster_dense_units: ', [[[848, 4]]])
# ('cluster_dense_units: ', [[[849, 4]]])
# ('cluster_dense_units: ', [[[851, 1]], [[851, 2]]])
# ('cluster_dense_units: ', [[[854, 4]], [[854, 5]]])
# ('cluster_dense_units: ', [[[855, 4]]])
# ('cluster_dense_units: ', [[[856, 6]]])
# ('cluster_dense_units: ', [[[857, 6]], [[857, 7]]])
# ('cluster_dense_units: ', [[[858, 5]], [[858, 6]]])
# ('cluster_dense_units: ', [[[859, 4]], [[859, 5]]])
# ('cluster_dense_units: ', [[[860, 5]]])
# ('cluster_dense_units: ', [[[861, 4]]])
# ('cluster_dense_units: ', [[[862, 4]], [[862, 5]]])
# ('cluster_dense_units: ', [[[863, 5]]])
# ('cluster_dense_units: ', [[[864, 5]], [[864, 6]]])
# ('cluster_dense_units: ', [[[865, 4]], [[865, 5]]])
# ('cluster_dense_units: ', [[[866, 5]]])
# ('cluster_dense_units: ', [[[867, 5]]])
# ('cluster_dense_units: ', [[[868, 6]], [[868, 7]]])
# ('cluster_dense_units: ', [[[869, 4]]])
# ('cluster_dense_units: ', [[[870, 5]]])
# ('cluster_dense_units: ', [[[871, 4]]])
# ('cluster_dense_units: ', [[[872, 3]]])
# ('cluster_dense_units: ', [[[873, 5]]])
# ('cluster_dense_units: ', [[[874, 4]]])
# ('cluster_dense_units: ', [[[877, 4]], [[877, 5]]])
# ('cluster_dense_units: ', [[[878, 5]], [[878, 6]]])
# ('cluster_dense_units: ', [[[879, 6]]])
# ('cluster_dense_units: ', [[[880, 5]]])
# ('cluster_dense_units: ', [[[881, 2]], [[881, 3]]])
# ('cluster_dense_units: ', [[[882, 6]]])
# ('cluster_dense_units: ', [[[883, 6]]])
# ('cluster_dense_units: ', [[[884, 6]]])
# ('cluster_dense_units: ', [[[885, 4]]])
# ('cluster_dense_units: ', [[[886, 6]]])
# ('cluster_dense_units: ', [[[887, 5]]])
# ('cluster_dense_units: ', [[[888, 6]]])
# ('cluster_dense_units: ', [[[890, 1]], [[890, 2]]])
# ('cluster_dense_units: ', [[[893, 3]]])
# ('cluster_dense_units: ', [[[894, 3]], [[894, 4]]])
# ('cluster_dense_units: ', [[[895, 4]]])
# ('cluster_dense_units: ', [[[898, 3]]])
# ('cluster_dense_units: ', [[[898, 5]]])
# ('cluster_dense_units: ', [[[899, 5]]])
# ('cluster_dense_units: ', [[[901, 4]], [[901, 5]]])
# ('cluster_dense_units: ', [[[902, 5]]])
# ('cluster_dense_units: ', [[[903, 4]]])
# ('cluster_dense_units: ', [[[904, 6]]])
# ('cluster_dense_units: ', [[[905, 5]]])
# ('cluster_dense_units: ', [[[906, 6]]])
# ('cluster_dense_units: ', [[[908, 3]]])
# ('cluster_dense_units: ', [[[910, 3]]])
# ('cluster_dense_units: ', [[[911, 2]], [[911, 3]]])
# ('cluster_dense_units: ', [[[912, 2]], [[912, 3]]])
# ('cluster_dense_units: ', [[[913, 3]], [[913, 4]]])
# ('cluster_dense_units: ', [[[914, 3]]])
# ('cluster_dense_units: ', [[[915, 4]], [[915, 5]]])
# ('cluster_dense_units: ', [[[916, 2]], [[916, 3]]])
# ('cluster_dense_units: ', [[[917, 3]], [[917, 4]]])
# ('cluster_dense_units: ', [[[918, 2]]])
# ('cluster_dense_units: ', [[[918, 4]]])
# ('cluster_dense_units: ', [[[920, 5]]])
# ('cluster_dense_units: ', [[[921, 2]]])
# ('cluster_dense_units: ', [[[922, 5]]])
# ('cluster_dense_units: ', [[[923, 5]]])
# ('cluster_dense_units: ', [[[924, 6]], [[924, 7]]])
# ('cluster_dense_units: ', [[[925, 5]]])
# ('cluster_dense_units: ', [[[926, 4]], [[926, 5]]])
# ('cluster_dense_units: ', [[[927, 3]]])
# ('cluster_dense_units: ', [[[928, 4]]])
# ('cluster_dense_units: ', [[[929, 2]], [[929, 3]]])
# ('cluster_dense_units: ', [[[930, 5]]])
# ('cluster_dense_units: ', [[[931, 5]], [[931, 6]]])
# ('cluster_dense_units: ', [[[932, 5]]])
# ('cluster_dense_units: ', [[[932, 7]]])
# ('cluster_dense_units: ', [[[933, 5]]])
# ('cluster_dense_units: ', [[[935, 4]]])
# ('cluster_dense_units: ', [[[936, 6]]])
# ('cluster_dense_units: ', [[[937, 5]], [[937, 6]]])
# ('cluster_dense_units: ', [[[938, 5]]])
# ('cluster_dense_units: ', [[[939, 5]]])
# ('cluster_dense_units: ', [[[941, 3]]])
# ('cluster_dense_units: ', [[[942, 3]], [[942, 4]]])
# ('cluster_dense_units: ', [[[943, 4]], [[943, 5]]])
# ('cluster_dense_units: ', [[[944, 3]]])
# ('cluster_dense_units: ', [[[945, 3]], [[945, 4]]])
# ('cluster_dense_units: ', [[[946, 3]], [[946, 4]]])
# ('cluster_dense_units: ', [[[947, 4]], [[947, 5]]])
# ('cluster_dense_units: ', [[[948, 3]], [[948, 4]]])
# ('cluster_dense_units: ', [[[949, 2]], [[949, 3]]])
# ('cluster_dense_units: ', [[[951, 4]], [[951, 5]]])
# ('cluster_dense_units: ', [[[954, 2]], [[954, 3]]])
# ('cluster_dense_units: ', [[[955, 3]]])
# ('cluster_dense_units: ', [[[956, 4]], [[956, 5]], [[956, 6]]])
# ('cluster_dense_units: ', [[[957, 5]]])
# ('cluster_dense_units: ', [[[958, 5]]])
# ('cluster_dense_units: ', [[[959, 3]], [[959, 4]]])
# ('cluster_dense_units: ', [[[960, 4]], [[960, 5]]])
# ('cluster_dense_units: ', [[[961, 4]], [[961, 5]], [[961, 6]]])
# ('cluster_dense_units: ', [[[962, 4]], [[962, 5]]])
# ('cluster_dense_units: ', [[[963, 6]]])
# ('cluster_dense_units: ', [[[964, 5]]])
# ('cluster_dense_units: ', [[[965, 3]], [[965, 4]], [[965, 5]]])
# ('cluster_dense_units: ', [[[966, 6]]])
# ('cluster_dense_units: ', [[[967, 3]], [[967, 4]]])
# ('cluster_dense_units: ', [[[968, 4]], [[968, 5]]])
# ('cluster_dense_units: ', [[[969, 4]]])
# ('cluster_dense_units: ', [[[970, 4]]])
# ('cluster_dense_units: ', [[[971, 5]]])
# ('cluster_dense_units: ', [[[972, 5]]])
# ('cluster_dense_units: ', [[[973, 6]]])
# ('cluster_dense_units: ', [[[974, 5]]])
# ('cluster_dense_units: ', [[[975, 4]]])
# ('cluster_dense_units: ', [[[976, 4]], [[976, 5]]])
# ('cluster_dense_units: ', [[[977, 3]]])
# ('cluster_dense_units: ', [[[978, 5]], [[978, 6]]])
# ('cluster_dense_units: ', [[[979, 5]], [[979, 6]]])
# ('cluster_dense_units: ', [[[981, 3]]])
# ('cluster_dense_units: ', [[[982, 2]], [[982, 3]]])
# ('cluster_dense_units: ', [[[984, 4]], [[984, 5]]])
# ('cluster_dense_units: ', [[[985, 4]]])
# ('cluster_dense_units: ', [[[986, 4]]])
# ('cluster_dense_units: ', [[[987, 4]], [[987, 5]]])
# ('cluster_dense_units: ', [[[988, 4]]])
# ('cluster_dense_units: ', [[[989, 4]]])
# ('cluster_dense_units: ', [[[990, 3]], [[990, 4]], [[990, 5]]])
# ('cluster_dense_units: ', [[[991, 5]]])
# ('cluster_dense_units: ', [[[992, 4]]])
# ('cluster_dense_units: ', [[[993, 5]]])
# ('cluster_dense_units: ', [[[994, 1]], [[994, 2]]])
# ('cluster_dense_units: ', [[[995, 1]], [[995, 2]]])
# ('cluster_dense_units: ', [[[996, 3]], [[996, 4]]])
# ('cluster_dense_units: ', [[[997, 2]]])
# ('cluster_dense_units: ', [[[998, 3]], [[998, 4]]])
# ('cluster_dense_units: ', [[[999, 4]]])
# ('cluster_dense_units: ', [[[1000, 4]], [[1000, 5]]])
# ('cluster_dense_units: ', [[[1001, 4]]])
# ('cluster_dense_units: ', [[[1002, 4]], [[1002, 5]]])
# ('cluster_dense_units: ', [[[1004, 3]], [[1004, 4]]])
# ('cluster_dense_units: ', [[[1008, 4]]])
# ('cluster_dense_units: ', [[[1013, 5]]])
# ('cluster_dense_units: ', [[[1014, 8]]])
# ('cluster_dense_units: ', [[[1016, 6]]])
# ('cluster_dense_units: ', [[[1017, 4]]])
# ('cluster_dense_units: ', [[[1018, 4]]])
# ('cluster_dense_units: ', [[[1019, 6]], [[1019, 7]]])
# ('cluster_dense_units: ', [[[1020, 6]], [[1020, 7]]])
# ('cluster_dense_units: ', [[[1021, 6]], [[1021, 7]]])
# ('cluster_dense_units: ', [[[1022, 5]]])
# ('cluster_dense_units: ', [[[1023, 5]]])
# ('cluster_dense_units: ', [[[1026, 4]], [[1026, 5]]])
# ('cluster_dense_units: ', [[[1027, 4]]])
# ('cluster_dense_units: ', [[[1028, 3]]])
# ('cluster_dense_units: ', [[[1029, 3]]])
# ('cluster_dense_units: ', [[[1030, 6]]])
# ('cluster_dense_units: ', [[[1031, 5]]])
# ('cluster_dense_units: ', [[[1032, 4]], [[1032, 5]]])
# ('cluster_dense_units: ', [[[1034, 4]]])
# ('cluster_dense_units: ', [[[1034, 6]]])
# ('cluster_dense_units: ', [[[1035, 5]], [[1035, 6]]])
# ('cluster_dense_units: ', [[[1036, 3]], [[1036, 4]]])
# ('cluster_dense_units: ', [[[1037, 4]]])
# ('cluster_dense_units: ', [[[1038, 6]]])
# ('cluster_dense_units: ', [[[1039, 2]], [[1039, 3]]])
# ('cluster_dense_units: ', [[[1040, 4]], [[1040, 5]]])
# ('cluster_dense_units: ', [[[1041, 4]]])
# ('cluster_dense_units: ', [[[1042, 4]]])
# ('cluster_dense_units: ', [[[1043, 6]], [[1043, 7]]])
# ('cluster_dense_units: ', [[[1044, 5]]])
# ('cluster_dense_units: ', [[[1045, 5]]])
# ('cluster_dense_units: ', [[[1046, 4]]])
# ('cluster_dense_units: ', [[[1047, 5]]])
# ('cluster_dense_units: ', [[[1048, 4]], [[1048, 5]]])
# ('cluster_dense_units: ', [[[1049, 5]]])
# ('cluster_dense_units: ', [[[1050, 4]]])
# ('cluster_dense_units: ', [[[1051, 6]]])
# ('cluster_dense_units: ', [[[1053, 6]]])
# ('cluster_dense_units: ', [[[1054, 4]]])
# ('cluster_dense_units: ', [[[1055, 4]]])
# ('cluster_dense_units: ', [[[1056, 4]]])
# ('cluster_dense_units: ', [[[1057, 4]]])
# ('cluster_dense_units: ', [[[1057, 6]]])
# ('cluster_dense_units: ', [[[1058, 4]]])
# ('cluster_dense_units: ', [[[1059, 5]], [[1059, 6]]])
# ('cluster_dense_units: ', [[[1060, 5]]])
# ('cluster_dense_units: ', [[[1061, 5]]])
# ('cluster_dense_units: ', [[[1062, 3]], [[1062, 4]]])
# ('cluster_dense_units: ', [[[1063, 5]]])
# ('cluster_dense_units: ', [[[1064, 7]]])
# ('cluster_dense_units: ', [[[1065, 6]], [[1065, 7]]])
# ('cluster_dense_units: ', [[[1066, 6]], [[1066, 7]]])
# ('cluster_dense_units: ', [[[1067, 6]], [[1067, 7]]])
# ('cluster_dense_units: ', [[[1068, 6]], [[1068, 7]]])
# ('cluster_dense_units: ', [[[1069, 5]]])
# ('cluster_dense_units: ', [[[1070, 5]]])
# ('cluster_dense_units: ', [[[1071, 4]], [[1071, 5]]])
# ('cluster_dense_units: ', [[[1072, 4]], [[1072, 5]]])
# ('cluster_dense_units: ', [[[1073, 4]]])
# ('cluster_dense_units: ', [[[1075, 2]], [[1075, 3]]])
# ('cluster_dense_units: ', [[[1076, 3]], [[1076, 4]]])
# ('cluster_dense_units: ', [[[1077, 4]]])
# ('cluster_dense_units: ', [[[1078, 4]]])
# ('cluster_dense_units: ', [[[1080, 5]]])
# ('cluster_dense_units: ', [[[1081, 6]]])
# ('cluster_dense_units: ', [[[1082, 6]], [[1082, 7]]])
# ('cluster_dense_units: ', [[[1083, 4]], [[1083, 5]]])
# ('cluster_dense_units: ', [[[1084, 4]]])
# ('cluster_dense_units: ', [[[1085, 4]]])
# ('cluster_dense_units: ', [[[1086, 3]], [[1086, 4]]])
# ('cluster_dense_units: ', [[[1087, 1]]])
# ('cluster_dense_units: ', [[[1088, 1]], [[1088, 2]]])
# ('cluster_dense_units: ', [[[1089, 0]], [[1089, 1]], [[1089, 2]]])
# ('cluster_dense_units: ', [[[1090, 5]]])
# ('cluster_dense_units: ', [[[1091, 4]]])
# ('cluster_dense_units: ', [[[1092, 5]]])
# ('cluster_dense_units: ', [[[1093, 4]]])
# ('cluster_dense_units: ', [[[1094, 4]]])
# ('cluster_dense_units: ', [[[1095, 3]], [[1095, 4]]])
# ('cluster_dense_units: ', [[[1096, 4]], [[1096, 5]]])
# ('cluster_dense_units: ', [[[1097, 3]], [[1097, 4]]])
# ('cluster_dense_units: ', [[[1099, 5]]])
# ('cluster_dense_units: ', [[[1100, 5]]])
# ('cluster_dense_units: ', [[[1101, 5]]])
# ('cluster_dense_units: ', [[[1102, 4]]])
# ('cluster_dense_units: ', [[[1103, 4]], [[1103, 5]]])
# ('cluster_dense_units: ', [[[1104, 4]], [[1104, 5]]])
# ('cluster_dense_units: ', [[[1105, 5]]])
# ('cluster_dense_units: ', [[[1106, 6]]])
# ('cluster_dense_units: ', [[[1107, 5]]])
# ('cluster_dense_units: ', [[[1108, 5]]])
# ('cluster_dense_units: ', [[[1109, 5]]])
# ('cluster_dense_units: ', [[[1110, 3]], [[1110, 4]]])
# ('cluster_dense_units: ', [[[1111, 4]]])
# ('cluster_dense_units: ', [[[1113, 4]]])
# ('cluster_dense_units: ', [[[1114, 2]]])
# ('cluster_dense_units: ', [[[1115, 5]]])
# ('cluster_dense_units: ', [[[1116, 5]]])
# ('cluster_dense_units: ', [[[1117, 3]]])
# ('cluster_dense_units: ', [[[1118, 2]], [[1118, 3]]])
# ('cluster_dense_units: ', [[[1119, 5]], [[1119, 6]]])
# ('cluster_dense_units: ', [[[1120, 5]]])
# ('cluster_dense_units: ', [[[1121, 4]]])
# ('cluster_dense_units: ', [[[1122, 3]]])
# ('cluster_dense_units: ', [[[1123, 4]]])
# ('cluster_dense_units: ', [[[1124, 4]], [[1124, 5]]])
# ('cluster_dense_units: ', [[[1125, 5]], [[1125, 6]]])
# ('cluster_dense_units: ', [[[1126, 4]]])
# ('cluster_dense_units: ', [[[1127, 5]]])
# ('cluster_dense_units: ', [[[1129, 6]]])
# ('cluster_dense_units: ', [[[1131, 6]], [[1131, 7]]])
# ('cluster_dense_units: ', [[[1133, 4]]])
# ('cluster_dense_units: ', [[[1134, 3]]])
# ('cluster_dense_units: ', [[[1135, 5]]])
# ('cluster_dense_units: ', [[[1136, 2]], [[1136, 3]]])
# ('cluster_dense_units: ', [[[1137, 3]]])
# ('cluster_dense_units: ', [[[1138, 4]]])
# ('cluster_dense_units: ', [[[1139, 5]]])
# ('cluster_dense_units: ', [[[1142, 3]], [[1142, 4]]])
# ('cluster_dense_units: ', [[[1143, 5]], [[1143, 6]]])
# ('cluster_dense_units: ', [[[1144, 4]]])
# ('cluster_dense_units: ', [[[1146, 4]]])
# ('cluster_dense_units: ', [[[1147, 3]], [[1147, 4]]])
# ('cluster_dense_units: ', [[[1148, 5]]])
# ('cluster_dense_units: ', [[[1149, 5]]])
# ('cluster_dense_units: ', [[[1150, 4]]])
# ('cluster_dense_units: ', [[[1151, 5]]])
# ('cluster_dense_units: ', [[[1152, 3]], [[1152, 4]]])
# ('cluster_dense_units: ', [[[1153, 3]]])
# ('cluster_dense_units: ', [[[1154, 3]]])
# ('cluster_dense_units: ', [[[1155, 4]]])
# ('cluster_dense_units: ', [[[1160, 6]]])
# ('cluster_dense_units: ', [[[1161, 4]], [[1161, 5]]])
# ('cluster_dense_units: ', [[[1162, 4]]])
# ('cluster_dense_units: ', [[[1163, 3]], [[1163, 4]]])
# ...
# ('cluster_dense_units: ', [[[3630, 5]]])
# ('cluster_dense_units: ', [[[3631, 4]]])
# ('cluster_dense_units: ', [[[3632, 4]]])
# ('cluster_dense_units: ', [[[3633, 4]], [[3633, 5]], [[3633, 6]]])
# ('cluster_dense_units: ', [[[3634, 4]]])
# ('cluster_dense_units: ', [[[3636, 5]], [[3636, 6]]])
# ('cluster_dense_units: ', [[[3637, 5]]])
# ('cluster_dense_units: ', [[[3638, 5]]])
# ('cluster_dense_units: ', [[[3639, 6]], [[3639, 7]]])
# ('cluster_dense_units: ', [[[3640, 5]], [[3640, 6]]])
# ('cluster_dense_units: ', [[[3641, 5]], [[3641, 6]]])
# ('cluster_dense_units: ', [[[3642, 5]]])
# ('cluster_dense_units: ', [[[3643, 5]]])
# ('cluster_dense_units: ', [[[3644, 5]], [[3644, 6]]])
# ('cluster_dense_units: ', [[[3645, 5]], [[3645, 6]]])
# ('cluster_dense_units: ', [[[3646, 5]], [[3646, 6]]])
# ('cluster_dense_units: ', [[[3647, 5]], [[3647, 6]]])
# ('cluster_dense_units: ', [[[3648, 5]], [[3648, 6]]])
# ('cluster_dense_units: ', [[[3649, 5]]])
# ('cluster_dense_units: ', [[[3650, 4]]])
# ('cluster_dense_units: ', [[[3651, 5]]])
# ('cluster_dense_units: ', [[[3652, 5]]])
# ('cluster_dense_units: ', [[[3653, 5]], [[3653, 6]]])
# ('cluster_dense_units: ', [[[3654, 4]], [[3654, 5]]])
# ('cluster_dense_units: ', [[[3656, 4]]])
# ('cluster_dense_units: ', [[[3657, 5]], [[3657, 6]]])
# ('cluster_dense_units: ', [[[3658, 4]], [[3658, 5]]])
# ('cluster_dense_units: ', [[[3659, 3]], [[3659, 4]]])
# ('cluster_dense_units: ', [[[3660, 3]], [[3660, 4]]])
# ('cluster_dense_units: ', [[[3661, 3]], [[3661, 4]]])
# ('cluster_dense_units: ', [[[3662, 3]], [[3662, 4]]])
# ('cluster_dense_units: ', [[[3663, 4]], [[3663, 5]]])
# ('cluster_dense_units: ', [[[3664, 6]]])
# ('cluster_dense_units: ', [[[3665, 5]], [[3665, 6]]])
# ('cluster_dense_units: ', [[[3666, 5]]])
# ('cluster_dense_units: ', [[[3667, 3]], [[3667, 4]], [[3667, 5]]])
# ('cluster_dense_units: ', [[[3668, 4]], [[3668, 5]]])
# ('cluster_dense_units: ', [[[3669, 6]]])
# ('cluster_dense_units: ', [[[3670, 3]]])
# ('cluster_dense_units: ', [[[3671, 4]], [[3671, 5]]])
# ('cluster_dense_units: ', [[[3672, 4]], [[3672, 5]]])
# ('cluster_dense_units: ', [[[3674, 5]], [[3674, 6]]])
# ('cluster_dense_units: ', [[[3675, 4]], [[3675, 5]]])
# ('cluster_dense_units: ', [[[3676, 6]]])
# ('cluster_dense_units: ', [[[3677, 4]], [[3677, 5]]])
# ('cluster_dense_units: ', [[[3678, 4]], [[3678, 5]]])
# ('cluster_dense_units: ', [[[3679, 2]]])
# ('cluster_dense_units: ', [[[3680, 4]]])
# ('cluster_dense_units: ', [[[3681, 5]]])
# ('cluster_dense_units: ', [[[3682, 3]]])
# ('cluster_dense_units: ', [[[3683, 5]], [[3683, 6]], [[3683, 7]]])
# ('cluster_dense_units: ', [[[3684, 5]]])
# ('cluster_dense_units: ', [[[3685, 5]]])
# ('cluster_dense_units: ', [[[3686, 4]]])
# ('cluster_dense_units: ', [[[3687, 5]]])
# ('cluster_dense_units: ', [[[3688, 2]]])
# ('cluster_dense_units: ', [[[3689, 2]]])
# ('cluster_dense_units: ', [[[3689, 4]]])
# ('cluster_dense_units: ', [[[3690, 4]]])
# ('cluster_dense_units: ', [[[3691, 1]], [[3691, 2]]])
# ('cluster_dense_units: ', [[[3692, 2]]])
# ('cluster_dense_units: ', [[[3693, 2]], [[3693, 3]]])
# ('cluster_dense_units: ', [[[3694, 5]]])
# ('cluster_dense_units: ', [[[3695, 4]]])
# ('cluster_dense_units: ', [[[3696, 4]]])
# ('cluster_dense_units: ', [[[3697, 3]]])
# ('cluster_dense_units: ', [[[3698, 3]], [[3698, 4]]])
# ('cluster_dense_units: ', [[[3699, 4]], [[3699, 5]]])
# ('cluster_dense_units: ', [[[3700, 1]], [[3700, 2]]])
# ('cluster_dense_units: ', [[[3701, 3]]])
# ('cluster_dense_units: ', [[[3702, 6]]])
# ('cluster_dense_units: ', [[[3705, 6]]])
# ('cluster_dense_units: ', [[[3706, 6]]])
# ('cluster_dense_units: ', [[[3707, 5]]])
# ('cluster_dense_units: ', [[[3708, 6]]])
# ('cluster_dense_units: ', [[[3709, 5]]])
# ('cluster_dense_units: ', [[[3710, 5]]])
# ('cluster_dense_units: ', [[[3711, 5]]])
# ('cluster_dense_units: ', [[[3712, 5]]])
# ('cluster_dense_units: ', [[[3713, 4]]])
# ('cluster_dense_units: ', [[[3714, 2]], [[3714, 3]]])
# ('cluster_dense_units: ', [[[3715, 3]]])
# ('cluster_dense_units: ', [[[3716, 3]]])
# ('cluster_dense_units: ', [[[3718, 4]]])
# ('cluster_dense_units: ', [[[3721, 3]], [[3721, 4]]])
# ('cluster_dense_units: ', [[[3722, 5]]])
# ('cluster_dense_units: ', [[[3723, 3]]])
# ('cluster_dense_units: ', [[[3723, 5]]])
# ('cluster_dense_units: ', [[[3724, 5]]])
# ('cluster_dense_units: ', [[[3725, 4]]])
# ('cluster_dense_units: ', [[[3726, 4]]])
# ('cluster_dense_units: ', [[[3727, 4]]])
# ('cluster_dense_units: ', [[[3728, 5]]])
# ('cluster_dense_units: ', [[[3729, 2]]])
# ('cluster_dense_units: ', [[[3738, 3]]])
# ('cluster_dense_units: ', [[[3739, 4]]])
# ('cluster_dense_units: ', [[[3740, 4]]])
# ('cluster_dense_units: ', [[[3741, 4]]])
# ('cluster_dense_units: ', [[[3742, 3]]])
# ('cluster_dense_units: ', [[[3744, 4]]])
# ('cluster_dense_units: ', [[[3744, 6]]])
# ('cluster_dense_units: ', [[[3745, 2]]])
# ('cluster_dense_units: ', [[[3748, 3]]])
# ('cluster_dense_units: ', [[[3750, 2]]])
# ('cluster_dense_units: ', [[[3751, 2]]])
# ('cluster_dense_units: ', [[[3752, 1]]])
# ('cluster_dense_units: ', [[[3753, 2]]])
# ('cluster_dense_units: ', [[[3754, 3]]])
# ('cluster_dense_units: ', [[[3755, 1]]])
# ('cluster_dense_units: ', [[[3756, 4]]])
# ('cluster_dense_units: ', [[[3760, 4]]])
# ('cluster_dense_units: ', [[[3761, 7]]])
# ('cluster_dense_units: ', [[[3762, 2]]])
# ('cluster_dense_units: ', [[[3763, 4]]])
# ('cluster_dense_units: ', [[[3764, 4]]])
# ('cluster_dense_units: ', [[[3765, 4]]])
# ('cluster_dense_units: ', [[[3766, 3]]])
# ('cluster_dense_units: ', [[[3767, 4]]])
# ('cluster_dense_units: ', [[[3768, 3]]])
# ('cluster_dense_units: ', [[[3769, 2]], [[3769, 3]]])
# ('cluster_dense_units: ', [[[3770, 2]], [[3770, 3]]])
# ('cluster_dense_units: ', [[[3771, 3]]])
# ('cluster_dense_units: ', [[[3772, 0]]])
# ('cluster_dense_units: ', [[[3772, 2]]])
# ('cluster_dense_units: ', [[[3773, 1]], [[3773, 2]]])
# ('cluster_dense_units: ', [[[3774, 3]]])
# ('cluster_dense_units: ', [[[3775, 1]]])
# ('cluster_dense_units: ', [[[3778, 4]]])
# ('cluster_dense_units: ', [[[3779, 4]]])
# ('cluster_dense_units: ', [[[3780, 4]]])
# ('cluster_dense_units: ', [[[3782, 2]]])
# ('cluster_dense_units: ', [[[3783, 2]], [[3783, 3]]])
# ('cluster_dense_units: ', [[[3784, 2]]])
# ('cluster_dense_units: ', [[[3784, 4]]])
# ('cluster_dense_units: ', [[[3785, 1]]])
# ('cluster_dense_units: ', [[[3788, 1]]])
# ('cluster_dense_units: ', [[[3788, 4]]])
# ('cluster_dense_units: ', [[[3789, 1]]])
# ('cluster_dense_units: ', [[[3789, 3]]])
# ('cluster_dense_units: ', [[[3790, 1]]])
# ('cluster_dense_units: ', [[[3791, 1]]])
# ('cluster_dense_units: ', [[[3792, 2]]])
# ('cluster_dense_units: ', [[[3793, 1]]])
# ('cluster_dense_units: ', [[[3794, 0]], [[3794, 1]]])
# ('cluster_dense_units: ', [[[3795, 1]]])
# ('cluster_dense_units: ', [[[3796, 3]]])
# ('cluster_dense_units: ', [[[3798, 2]], [[3798, 3]]])
# ('cluster_dense_units: ', [[[3799, 2]]])
# ('cluster_dense_units: ', [[[3802, 3]]])
# ('cluster_dense_units: ', [[[3804, 1]]])
# ('cluster_dense_units: ', [[[3805, 4]]])
# ('cluster_dense_units: ', [[[3806, 1]], [[3806, 2]]])
# ('cluster_dense_units: ', [[[3807, 3]]])
# ('cluster_dense_units: ', [[[3808, 2]], [[3808, 3]]])
# ('cluster_dense_units: ', [[[3809, 3]]])
# ('cluster_dense_units: ', [[[3810, 3]]])
# ('cluster_dense_units: ', [[[3811, 3]]])
# ('cluster_dense_units: ', [[[3812, 4]]])
# ('cluster_dense_units: ', [[[3813, 2]], [[3813, 3]], [[3813, 4]]])
# ('cluster_dense_units: ', [[[3814, 5]]])
# ('cluster_dense_units: ', [[[3815, 3]], [[3815, 4]]])
# ('cluster_dense_units: ', [[[3816, 4]]])
# ('cluster_dense_units: ', [[[3817, 4]]])
# ('cluster_dense_units: ', [[[3818, 4]]])
# ('cluster_dense_units: ', [[[3819, 3]], [[3819, 4]]])
# ('cluster_dense_units: ', [[[3820, 3]]])
# ('cluster_dense_units: ', [[[3821, 3]]])
# ('cluster_dense_units: ', [[[3823, 5]]])
# ('cluster_dense_units: ', [[[3824, 6]]])
# ('cluster_dense_units: ', [[[3825, 4]], [[3825, 5]]])
# ('cluster_dense_units: ', [[[3826, 5]], [[3826, 6]]])
# ('cluster_dense_units: ', [[[3827, 4]]])
# ('cluster_dense_units: ', [[[3828, 5]]])
# ('cluster_dense_units: ', [[[3829, 4]]])
# ('cluster_dense_units: ', [[[3830, 5]]])
# ('cluster_dense_units: ', [[[3831, 4]]])
# ('cluster_dense_units: ', [[[3832, 4]]])
# ('cluster_dense_units: ', [[[3833, 4]]])
# ('cluster_dense_units: ', [[[3834, 2]], [[3834, 3]]])
# ('cluster_dense_units: ', [[[3835, 2]]])
# ('cluster_dense_units: ', [[[3836, 3]]])
# ('cluster_dense_units: ', [[[3836, 5]]])
# ('cluster_dense_units: ', [[[3837, 5]]])
# ('cluster_dense_units: ', [[[3839, 2]]])
# ('cluster_dense_units: ', [[[3840, 4]]])
# ('cluster_dense_units: ', [[[3842, 5]]])
# ('cluster_dense_units: ', [[[3843, 5]]])
# ('cluster_dense_units: ', [[[3844, 6]]])
# ('cluster_dense_units: ', [[[3845, 4]]])
# ('cluster_dense_units: ', [[[3846, 4]]])
# ('cluster_dense_units: ', [[[3847, 5]]])
# ('cluster_dense_units: ', [[[3849, 6]]])
# ('cluster_dense_units: ', [[[3850, 7]]])
# ('cluster_dense_units: ', [[[3851, 6]], [[3851, 7]]])
# ('cluster_dense_units: ', [[[3852, 5]]])
# ('cluster_dense_units: ', [[[3853, 7]]])
# ('cluster_dense_units: ', [[[3855, 6]], [[3855, 7]]])
# ('cluster_dense_units: ', [[[3861, 4]]])
# ('cluster_dense_units: ', [[[3862, 4]]])
# ('cluster_dense_units: ', [[[3863, 6]]])
# ('cluster_dense_units: ', [[[3864, 4]]])
# ('cluster_dense_units: ', [[[3866, 3]]])
# ('cluster_dense_units: ', [[[3868, 3]]])
# ('cluster_dense_units: ', [[[3869, 2]]])
# ('cluster_dense_units: ', [[[3869, 4]]])
# ('cluster_dense_units: ', [[[3870, 3]]])
# ('cluster_dense_units: ', [[[3872, 3]], [[3872, 4]]])
# ('cluster_dense_units: ', [[[3873, 3]]])
# ('cluster_dense_units: ', [[[3874, 3]]])
# ('cluster_dense_units: ', [[[3875, 1]]])
# ('cluster_dense_units: ', [[[3879, 6]], [[3879, 7]]])
# ('cluster_dense_units: ', [[[3880, 5]]])
# ('cluster_dense_units: ', [[[3881, 3]], [[3881, 4]]])
# ('cluster_dense_units: ', [[[3882, 1]], [[3882, 2]]])
# ('cluster_dense_units: ', [[[3883, 2]], [[3883, 3]], [[3883, 4]]])
# ('cluster_dense_units: ', [[[3884, 4]]])
# ('cluster_dense_units: ', [[[3885, 4]]])
# ('cluster_dense_units: ', [[[3886, 4]], [[3886, 5]], [[3886, 6]]])
# ('cluster_dense_units: ', [[[3887, 5]], [[3887, 6]]])
# ('cluster_dense_units: ', [[[3888, 4]], [[3888, 5]]])
# ('cluster_dense_units: ', [[[3890, 3]]])
# ('cluster_dense_units: ', [[[3891, 3]]])
# ('cluster_dense_units: ', [[[3892, 4]]])
# ('cluster_dense_units: ', [[[3893, 3]], [[3893, 4]]])
# ('cluster_dense_units: ', [[[3894, 3]]])
# ('cluster_dense_units: ', [[[3895, 2]], [[3895, 3]]])
# ('cluster_dense_units: ', [[[3896, 3]], [[3896, 4]]])
# ('cluster_dense_units: ', [[[3897, 3]], [[3897, 4]]])
# ('cluster_dense_units: ', [[[3898, 4]]])
# ('cluster_dense_units: ', [[[3899, 4]]])
# ('cluster_dense_units: ', [[[3900, 4]], [[3900, 5]]])
# ('cluster_dense_units: ', [[[3901, 5]]])
# ('cluster_dense_units: ', [[[3902, 3]]])
# ('cluster_dense_units: ', [[[3902, 5]]])
# ('cluster_dense_units: ', [[[3903, 5]], [[3903, 6]]])
# ('cluster_dense_units: ', [[[3904, 2]]])
# ('cluster_dense_units: ', [[[3905, 3]], [[3905, 4]], [[3905, 5]]])
# ('cluster_dense_units: ', [[[3906, 6]]])
# ('cluster_dense_units: ', [[[3907, 3]], [[3907, 4]]])
# ('cluster_dense_units: ', [[[3908, 4]], [[3908, 5]]])
# ('cluster_dense_units: ', [[[3909, 5]], [[3909, 6]]])
# ('cluster_dense_units: ', [[[3910, 5]]])
# ('cluster_dense_units: ', [[[3911, 4]], [[3911, 5]], [[3911, 6]]])
# ('cluster_dense_units: ', [[[3912, 4]]])
# ('cluster_dense_units: ', [[[3913, 3]], [[3913, 4]]])
# ('cluster_dense_units: ', [[[3914, 4]]])
# ('cluster_dense_units: ', [[[3915, 3]], [[3915, 4]]])
# ('cluster_dense_units: ', [[[3916, 3]], [[3916, 4]]])
# ('cluster_dense_units: ', [[[3917, 1]]])
# ('cluster_dense_units: ', [[[3917, 3]]])
# ('cluster_dense_units: ', [[[3918, 4]]])
# ('cluster_dense_units: ', [[[3919, 3]], [[3919, 4]]])
# ('cluster_dense_units: ', [[[3920, 4]]])
# ('cluster_dense_units: ', [[[3921, 3]]])
# ('cluster_dense_units: ', [[[3922, 4]], [[3922, 5]]])
# ('cluster_dense_units: ', [[[3923, 2]], [[3923, 3]]])
# ('cluster_dense_units: ', [[[3924, 1]], [[3924, 2]]])
# ('cluster_dense_units: ', [[[3925, 3]]])
# ('cluster_dense_units: ', [[[3926, 3]], [[3926, 4]]])
# ('cluster_dense_units: ', [[[3927, 3]]])
# ('cluster_dense_units: ', [[[3928, 4]]])
# ('cluster_dense_units: ', [[[3929, 5]], [[3929, 6]], [[3929, 7]]])
# ('cluster_dense_units: ', [[[3930, 5]]])
# ('cluster_dense_units: ', [[[3931, 4]], [[3931, 5]]])
# ('cluster_dense_units: ', [[[3933, 5]], [[3933, 6]]])
# ('cluster_dense_units: ', [[[3934, 4]]])
# ('cluster_dense_units: ', [[[3935, 4]]])
# ('cluster_dense_units: ', [[[3936, 3]]])
# ('cluster_dense_units: ', [[[3939, 4]]])
# ('cluster_dense_units: ', [[[3940, 5]]])
# ('cluster_dense_units: ', [[[3942, 4]]])
# ('cluster_dense_units: ', [[[3944, 4]]])
# ('cluster_dense_units: ', [[[3945, 3]], [[3945, 4]]])
# ('cluster_dense_units: ', [[[3947, 4]], [[3947, 5]]])
# ('cluster_dense_units: ', [[[3948, 4]], [[3948, 5]]])
# ('cluster_dense_units: ', [[[3949, 4]]])
# ('cluster_dense_units: ', [[[3950, 4]]])
# ('cluster_dense_units: ', [[[3951, 4]], [[3951, 5]]])
# ('cluster_dense_units: ', [[[3952, 4]]])
# ('cluster_dense_units: ', [[[3953, 4]], [[3953, 5]]])
# ('cluster_dense_units: ', [[[3954, 4]]])
# ('cluster_dense_units: ', [[[3954, 6]]])
# ('cluster_dense_units: ', [[[3955, 4]]])
# ('cluster_dense_units: ', [[[3956, 3]], [[3956, 4]], [[3956, 5]]])
# ('cluster_dense_units: ', [[[3957, 4]], [[3957, 5]]])
# ('cluster_dense_units: ', [[[3958, 2]], [[3958, 3]]])
# ('cluster_dense_units: ', [[[3960, 5]], [[3960, 6]]])
# ('cluster_dense_units: ', [[[3961, 5]], [[3961, 6]]])
# ('cluster_dense_units: ', [[[3962, 2]]])
# ('cluster_dense_units: ', [[[3963, 3]]])
# ('cluster_dense_units: ', [[[3964, 3]], [[3964, 4]]])
# ('cluster_dense_units: ', [[[3965, 4]]])
# ('cluster_dense_units: ', [[[3966, 2]], [[3966, 3]], [[3966, 4]]])
# ('cluster_dense_units: ', [[[3968, 5]]])
# ('cluster_dense_units: ', [[[3969, 3]], [[3969, 4]]])
# ('cluster_dense_units: ', [[[3970, 3]]])
# ('cluster_dense_units: ', [[[3972, 3]], [[3972, 4]]])
# ('cluster_dense_units: ', [[[3973, 5]], [[3973, 6]]])
# ('cluster_dense_units: ', [[[3974, 3]]])
# ('cluster_dense_units: ', [[[3975, 4]], [[3975, 5]]])
# ('cluster_dense_units: ', [[[3976, 4]]])
# ('cluster_dense_units: ', [[[3977, 5]]])
# ('cluster_dense_units: ', [[[3978, 3]]])
# ('cluster_dense_units: ', [[[3980, 4]]])
# ('cluster_dense_units: ', [[[3981, 4]], [[3981, 5]]])
# ('cluster_dense_units: ', [[[3982, 4]]])
# ('cluster_dense_units: ', [[[3983, 5]]])
# ('cluster_dense_units: ', [[[3984, 4]], [[3984, 5]]])
# ('cluster_dense_units: ', [[[3985, 2]], [[3985, 3]]])
# ('cluster_dense_units: ', [[[3986, 1]], [[3986, 2]], [[3986, 3]]])
# ('cluster_dense_units: ', [[[3987, 2]], [[3987, 3]]])
# ('cluster_dense_units: ', [[[3988, 5]]])
# ('cluster_dense_units: ', [[[3992, 4]], [[3992, 5]]])
# ('cluster_dense_units: ', [[[3993, 6]], [[3993, 7]]])
# ('cluster_dense_units: ', [[[3994, 3]], [[3994, 4]]])
# ('cluster_dense_units: ', [[[3995, 5]]])
# ('cluster_dense_units: ', [[[3996, 4]], [[3996, 5]]])
# ('cluster_dense_units: ', [[[3997, 2]]])
# ('cluster_dense_units: ', [[[3998, 2]]])
# ('cluster_dense_units: ', [[[3998, 4]]])
# ('cluster_dense_units: ', [[[3999, 5]]])
# ('cluster_dense_units: ', [[[4000, 5]]])
# ('cluster_dense_units: ', [[[4001, 4]], [[4001, 5]]])
# ('cluster_dense_units: ', [[[4002, 4]]])
# ('cluster_dense_units: ', [[[4003, 5]]])
# ('cluster_dense_units: ', [[[4004, 5]]])
# ('cluster_dense_units: ', [[[4005, 4]], [[4005, 5]]])
# ('cluster_dense_units: ', [[[4006, 4]]])
# ('cluster_dense_units: ', [[[4007, 4]], [[4007, 5]]])
# ('cluster_dense_units: ', [[[4008, 4]], [[4008, 5]]])
# ('cluster_dense_units: ', [[[4009, 4]], [[4009, 5]]])
# ('cluster_dense_units: ', [[[4010, 4]]])
# ('cluster_dense_units: ', [[[4011, 6]]])
# ('cluster_dense_units: ', [[[4012, 4]], [[4012, 5]]])
# ('cluster_dense_units: ', [[[4013, 4]]])
# ('cluster_dense_units: ', [[[4014, 4]]])
# ('cluster_dense_units: ', [[[4015, 3]]])
# ('cluster_dense_units: ', [[[4016, 4]], [[4016, 5]]])
# ('cluster_dense_units: ', [[[4017, 3]], [[4017, 4]]])
# ('cluster_dense_units: ', [[[4018, 4]], [[4018, 5]]])
# ('cluster_dense_units: ', [[[4019, 5]], [[4019, 6]]])
# ('cluster_dense_units: ', [[[4020, 4]]])
# ('cluster_dense_units: ', [[[4022, 5]]])
# ('cluster_dense_units: ', [[[4023, 3]], [[4023, 4]]])
# ('cluster_dense_units: ', [[[4024, 4]], [[4024, 5]]])
# ('cluster_dense_units: ', [[[4025, 2]], [[4025, 3]]])
# ('cluster_dense_units: ', [[[4026, 0]], [[4026, 1]]])
# ('\n', '2', ' dimensional clusters:')
